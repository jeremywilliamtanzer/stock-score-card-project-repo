# %% [markdown]
# # API News exploration

# %% [markdown]
# ## Exploring Polygon API for news to conduct eventually NLP, sentiment analysis

# %%
#lib imports
import os
import langdetect
import requests
import pandas as pd
import numpy as np
import nltk
from gensim.models import Word2Vec
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
NEWS_KEY = os.environ.get('NEWS_KEY')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jtanzer/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
company = 'apple'
country = 'us'
url = f'https://newsapi.org/v2/everything?q={company}&from=2023-03-17&sortBy=publishedAt&apiKey={NEWS_KEY}'
#url = f'https://newsapi.org/v2/everything?q={country}&from=2023-03-17&to=2023-03-18&sortBy=popularity&apiKey={NEWS_KEY}'
response = requests.get(url)
response = response.json()
response
# Out:
# {'status': 'ok',
#  'totalResults': 5606,
#  'articles': [{'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Ollie Barder, Contributor, \n Ollie Barder, Contributor\n https://www.forbes.com/sites/olliebarder/',
#    'title': 'Henk Rogers On All Things ‘Tetris’, Including Its New Movie Adaptation',
#    'description': "The rights battle over the video game 'Tetris' are the stuff of games industry legend, which is something a new film is endeavoring to cover. So it only seemed fit to speak to Henk Rogers himself about how it all came about.",
#    'url': 'https://www.forbes.com/sites/olliebarder/2023/03/21/henk-rogers-on-all-things-tetris-including-its-new-movie-adaptation/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/641989fe477f13418fbdef19/0x0.jpg?format=jpg&crop=1071,603,x0,y88,safe&width=1200',
#    'publishedAt': '2023-03-21T11:02:02Z',
#    'content': 'AUSTIN, TEXAS - MARCH 15: Henk Rogers attends the "Tetris" world premiere at SXSW at The Paramount ... [+] Theatre on March 15, 2023 in Austin, Texas. (Photo by Rick Kern/FilmMagic)\r\nFilmMagic\r\nThe r… [+5621 chars]'},
#   {'source': {'id': None, 'name': 'Marketscreener.com'},
#    'author': 'MarketScreener',
#    'title': 'MACRO Announces Strategic Funding Round',
#    'description': '(marketscreener.com) \nMACRO, the multi-platform media company, founded by Charles D. King, today announced the completion of an over $90 million minority investment led by BlackRock Alternatives, through the BlackRock Impact Opportunities Fund and funds and a…',
#    'url': 'https://www.marketscreener.com/quote/stock/BLACKROCK-INC-11862/news/MACRO-Announces-Strategic-Funding-Round-43298775/?utm_medium=RSS&utm_content=20230321',
#    'urlToImage': 'https://www.marketscreener.com/images/twitter_MS_fdgris.png',
#    'publishedAt': '2023-03-21T11:02:01Z',
#    'content': 'MACRO, the multi-platform media company, founded by Charles D. King, today announced the completion of an over $90 million minority investment led by BlackRock Alternatives, through the BlackRock Imp… [+10054 chars]'},
#   {'source': {'id': None, 'name': 'Gizchina.com'},
#    'author': 'Abdullah',
#    'title': 'iPhone dominates 75% of the premium smartphone market',
#    'description': 'In 2022, the global smartphone market faced macroeconomic difficulties that led to a 12% YoY decline in overall sales. However, there was a contrasting growth ...\nThe post iPhone dominates 75% of the premium smartphone market appeared first on Gizchina.com.',
#    'url': 'https://www.gizchina.com/2023/03/21/iphone-dominates-75-of-the-premium-smartphone-market/',
#    'urlToImage': 'https://www.gizchina.com/wp-content/uploads/images/2022/12/iphone-camera.jpg',
#    'publishedAt': '2023-03-21T11:01:42Z',
#    'content': 'In 2022, the global smartphone market faced macroeconomic difficulties that led to a 12% YoY decline in overall sales. However, there was a contrasting growth in the global\xa0premium smartphone market,… [+4016 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Commanders Wire',
#    'title': 'Where do the Commanders rank among potential ‘Hard Knocks’ options?',
#    'description': 'There are four options. Could the Commanders appear on "Hard Knocks" for the first time?',
#    'url': 'https://commanderswire.usatoday.com/2023/03/21/where-do-the-washington-commanders-rank-among-potential-hard-knocks-options-2023-nfl-season/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/.yjALoXElCr6E74Q60JGyQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05MTQ-/https://media.zenfs.com/en/washington_football_wire_usa_today_sports_articles_166/c849272b60428c17f99f5c38a0f13853',
#    'publishedAt': '2023-03-21T11:01:20Z',
#    'content': 'The NFL began the Hard Knocks series all the way back in 2001 with the defending Super Bowl champion Baltimore Ravens. Over the years, 17 different NFL teams have been featured on the series, with th… [+2295 chars]'},
#   {'source': {'id': None, 'name': 'Gartner.com'},
#    'author': 'Hassan Ennaciri',
#    'title': 'You don’t have to be a MAAMA to start adopting Site Reliability Engineering (SRE) Practices.',
#    'description': 'I have taken many inquiries on Site Reliability Engineering (SRE) in the last couple of years.\xa0 I&O leaders are under high pressure to deliver reliable services at an unprecedented pace.\nThey want to consider SRE, but often worry it is an advanced practice th…',
#    'url': 'https://blogs.gartner.com/hassan-ennaciri/you-dont-have-to-be-a-maama-to-start-adopting-site-reliability-engineering-sre-practices/',
#    'urlToImage': 'https://emtemp.gcom.cloud/ngw/globalassets/gartner-tile.jpg',
#    'publishedAt': '2023-03-21T11:01:07Z',
#    'content': 'I have taken many inquiries on Site Reliability Engineering (SRE) in the last couple of years.\xa0 I&amp;O leaders are under high pressure to deliver reliable services at an unprecedented pace.They want… [+1025 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Talon Abernathy',
#    'title': 'No Checking Account? No Problem — Get One Simply at These 4 Banks',
#    'description': 'Maintaining a personal checking account is practically a necessity in this day and age. Unfortunately, many banks make opening new accounts a hassle. Find...',
#    'url': 'https://finance.yahoo.com/news/no-checking-account-no-problem-110103018.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/OIZtHoPUTZyemsFYdZjTfQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/gobankingrates_644/674d21742f9ef11a747f00df8d097d9a',
#    'publishedAt': '2023-03-21T11:01:03Z',
#    'content': 'Blend Images - JGI/Jamie Grill\r\nMaintaining a personal checking account is practically a necessity in this day and age. Unfortunately, many banks make opening new accounts a hassle.\r\nFind Out: Heres … [+4960 chars]'},
#   {'source': {'id': None, 'name': 'Maddyness.com'},
#    'author': 'Valentin Pringuay',
#    'title': '9 ans après sa création, Blue Frogs Robotics s’apprête à lancer la vente grand public de son robot Buddy',
#    'description': "L’article 9 ans après sa création, Blue Frogs Robotics s’apprête à lancer la vente grand public de son robot Buddy\xa0 est apparu en premier sur Maddyness - Le média pour comprendre l'économie de demain.",
#    'url': 'https://www.maddyness.com/2023/03/21/blue-frogs-robotics-buddy/',
#    'urlToImage': 'https://www.maddyness.com/app/uploads/2023/03/BUDDY_RODOLPHE_.png',
#    'publishedAt': '2023-03-21T11:00:59Z',
#    'content': 'Rodolphe Hasselvander a toujours rêvé de créer ses propres robots. Déjà à lâge de 8 ans, il annonçait vouloir devenir archéologue ou ingénieur en robotique : « Javais une maman qui travaillait dans u… [+6078 chars]'},
#   {'source': {'id': None, 'name': 'Tomshw.it'},
#    'author': 'Orazio Guastella',
#    'title': 'iPhone 15 Pro: Apple modificherà queste due componenti per la prima volta in 16 anni',
#    'description': 'Nuove indiscrezioni sui futuri iPhone 15 sbarcano sul web. Scopriamo insieme quali sono le nuove conferme riguardanti la nuova gamma in arrivo a fine anno.',
#    'url': 'https://www.tomshw.it/smartphone/iphone-15-pro-apple-modifichera-queste-due-componenti-per-la-prima-volta-in-16-anni/',
#    'urlToImage': 'https://www.tomshw.it/images/images/2022/09/iphone-14-pro-247309.jpg',
#    'publishedAt': '2023-03-21T11:00:46Z',
#    'content': "Apple iPhone 15 Pro: Apple modificherà queste due componenti per la prima volta in 16 anni\r\nTom's Hardware vive grazie al suo pubblico. Quando compri qualcosa dai nostri link, potremmo guadagnare una… [+3621 chars]"},
#   {'source': {'id': None, 'name': 'Xatakamovil.com'},
#    'author': 'Alejandro Alcolea',
#    'title': 'El iPhone 15 Pro romperá con el único elemento legado del iPhone original: adiós al interruptor de silencio, según filtraciones',
#    'description': 'Hace 16 años, Steve Jobs presentó el móvil más revolucionario de los últimos años, el iPhone. Es un terminal que estaba en pañales, pero que cambió el rumbo de la industria al introducir, de manera definitiva, un ordenador en el bolsillo. Desde su lanzamiento…',
#    'url': 'https://www.xatakamovil.com/nuevo/iphone-15-pro-rompera-unico-elemento-legado-iphone-original-adios-al-interruptor-silencio-filtraciones',
#    'urlToImage': 'https://i.blogs.es/df1590/slider/840_560.jpeg',
#    'publishedAt': '2023-03-21T11:00:35Z',
#    'content': 'Hace 16 años, Steve Jobs presentó el móvil más revolucionario de los últimos años, el iPhone. Es un terminal que estaba en pañales, pero que cambió el rumbo de la industria al introducir, de manera d… [+2378 chars]'},
#   {'source': {'id': None, 'name': 'Onliner.by'},
#    'author': 'Onliner',
#    'title': 'Письмо с редкой подписью Стива Джобса хотят пустить с молотка за $95 тысяч',
#    'description': 'Подписанное Стивом Джобсом благодарственное письмо выставлено на продажу — за него просят $95 тысяч. Этот лот — достаточно редкий. Стив почти никогда не раздавал автографы.Читать далее…',
#    'url': 'https://tech.onliner.by/2023/03/21/pismo-s-redkoj-podpisyu-stiva-dzhobsa-xotyat-pustit-s-molotka-za-95-tysyach',
#    'urlToImage': 'https://content.onliner.by/news/default/434864afbbece7555e244a9e9e210761.jpeg',
#    'publishedAt': '2023-03-21T11:00:33Z',
#    'content': '$95 . . .\r\n Apple . :\xa0« , Apple. Apple , , . , , , ».\r\n $95 ? . , , , , $500 .\r\n \xa0Telegram. !\r\n ? \xa0-.'},
#   {'source': {'id': None, 'name': 'Presse-citron'},
#    'author': 'Romain Vitt',
#    'title': 'Sur un marché en berne, les smartphones premium se portent bien (surtout les iPhone)',
#    'description': 'Le dernier rapport de Counterpoint sur les ventes de smartphones dans le monde montre que les modèles haut de gamme résistent mieux à la crise que les autres segments. Apple en profite largement grâce à son iPhone 14 qui cartonne.',
#    'url': 'https://www.presse-citron.net/sur-un-marche-en-berne-les-smartphones-premium-se-portent-bien-surtout-les-iphone/',
#    'urlToImage': 'https://www.presse-citron.net/app/uploads/2022/09/iphone-14-pro-gamme.jpg',
#    'publishedAt': '2023-03-21T11:00:30Z',
#    'content': '<ul><li>Le marché des smartphones sest écroulé en 2022 selon Counterpoint Research</li><li>Le segment Premium, lui, résiste mieux à la crise</li><li>Apple en sort grand gagnant</li></ul>Le marché mon… [+3349 chars]'},
#   {'source': {'id': None, 'name': 'Iphoneitalia.com'},
#    'author': 'Francesco Siciliani',
#    'title': 'Audible: tutti gli audiolibri su iPhone, iPad, Mac e CarPlay – RECENSIONE',
#    'description': "Audible è la più diffusa applicazione dedicata agli audiolibri, grazie alla quale è possibile acquistare e ascoltare interi libri.\nLink all'articolo originale: Audible: tutti gli audiolibri su iPhone, iPad, Mac e CarPlay – RECENSIONE",
#    'url': 'https://www.iphoneitalia.com/791716/audible-audiolibri-gratis-amazon-recensione',
#    'urlToImage': 'https://static.iphoneitalia.com/wp-content/uploads/2023/01/Audible.jpg',
#    'publishedAt': '2023-03-21T11:00:26Z',
#    'content': 'Amazon mette a disposizione, con Audible, il suo catalogo di audiolibri in una sola applicazione, disponibile su iPhone, iPad, Mac e persino Apple CarPlay. Troviamo contenuti di altissima qualità e, … [+3261 chars]'},
#   {'source': {'id': None, 'name': 'Antyweb.pl'},
#    'author': 'Krzysztof Rojek',
#    'title': 'Zabicie serii iPhone mini było dobrą decyzją. Oto dlaczego',
#    'description': 'Przez ostatnie dwa lata mieliśmy na rynku kilka małych telefonów. Dane pokazują, dlaczego przez kolejne lata ich nie będzie.\n \n The post Zabicie serii iPhone mini było dobrą decyzją. Oto dlaczego appeared first on AntyWeb.',
#    'url': 'https://antyweb.pl/apple-iphone-14-plus-mini-sprzedaz',
#    'urlToImage': 'https://antyweb.pl/img/1250/550/fit/wp-content/uploads/2020/10/13194421/iPhone-12-Mini-1.jpg',
#    'publishedAt': '2023-03-21T11:00:23Z',
#    'content': 'W temacie telefonów w sieci od lat trwa walka pomidzy zwolennikami maych telefonów oraz urzdze z du przektn ekranu.\xa0 Ta pierwsza grupa jest duo goniejsza i w wielu miejscach moecie przeczyta, jak to … [+2194 chars]'},
#   {'source': {'id': None, 'name': 'Ipadizate.com'},
#    'author': 'Sergio J. Ortiz',
#    'title': 'Rusia prohíbe el iPhone a sus usuarios: "que lo tiren a la basura"',
#    'description': 'Después de que el director de WhatsApp atacase a Telegram de espionaje y ante la inminente llegada de las elecciones presidenciales, el Kremlin ha prohibido el uso de iPhone a sus oficiales debido a las preocupaciones existentes en relación a "la vulnerabilid…',
#    'url': 'https://ipadizate.com/iphone/rusia-prohibe-el-iphone-a-sus-usuarios-que-lo-tiren-a-la-basura',
#    'urlToImage': 'https://ipadizate.com/hero/2023/03/putin.1679394002.5699.jpg?width=1200',
#    'publishedAt': '2023-03-21T11:00:20Z',
#    'content': 'El gobierno ruso desea evitar filtraciones relacionadas con las elecciones\r\nDespués de que el director de WhatsApp atacase a Telegram de espionaje y ante la inminente llegada de las elecciones presid… [+2165 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Celtics Wire',
#    'title': 'Do the fans of the Boston Celtics expect too much from the team?',
#    'description': 'Is winning and momentum more important than playoff readiness and health?',
#    'url': 'https://celticswire.usatoday.com/2023/03/21/nba-boston-celtics-too-much/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/XpRBkQA0V8IKNzcex5LZnA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/celtics_wire_usa_today_sports_articles_699/9e5112a4d48f5541e410a4db4ae880db',
#    'publishedAt': '2023-03-21T11:00:17Z',
#    'content': 'Do the fans of the Boston Celtics expect too much from the team? On one hand, they want the ball club to win every game they can in the 2022-23 regular season. But on the other, they also want the te… [+869 chars]'},
#   {'source': {'id': None, 'name': 'Actualidadiphone.com'},
#    'author': 'Alex Vicente',
#    'title': 'La Xbox App Store podría llegar al iPhone el año que viene',
#    'description': 'Microsoft está preparándose para lanzar la Xbox App Store si la regulación obliga finalmente a Apple a abrir su ecosistema a terceros.',
#    'url': 'https://www.actualidadiphone.com/la-xbox-app-store-podria-llegar-al-iphone-el-ano-que-viene/',
#    'urlToImage': 'https://www.actualidadiphone.com/wp-content/uploads/2021/06/xbox-cloud-gaming.jpg',
#    'publishedAt': '2023-03-21T11:00:15Z',
#    'content': 'Microsoft ya está trabajando duro para prepararse para un mundo en el que Apple se vea obligada a permitir tiendas de aplicaciones de terceros en el iPhone. En una entrevista con el Financial Times, … [+2423 chars]'},
#   {'source': {'id': None, 'name': 'Nextpit.com'},
#    'author': 'Matthias "MaTT" Zellmer',
#    'title': 'Apple iPhone 15 Pro: Take a First Look at the Rumored "Taptic Buttons"',
#    'description': 'It is not a big secret that many leakers assume that the Apple iPhone 15 Pro (Max) will come with new "Taptic Buttons". Here is a first picture.(This is a preview - click here to read the entire entry.)',
#    'url': 'https://www.nextpit.com/apple-iphone-15-pro-new-taptic-buttons',
#    'urlToImage': 'https://fscl01.fonpit.de/userfiles/7687254/image/Apple_iPhone_14_Pro_Max/NextPit_Apple_iPhone_14_Pro_Max_Side.jpg',
#    'publishedAt': '2023-03-21T11:00:01Z',
#    'content': 'This is probably what the "taptic buttons" of the Apple iPhone 15 Pro will look like\r\nIt will be another six months before we get the Apple iPhone 15 series announced by Tim Cook. Nevertheless, tipst… [+1967 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': "'Wife Unwell, Son Abroad', Says Manish Sisodia In Bail Hearing. CBI Opposes - NDTV",
#    'description': "<ol><li>'Wife Unwell, Son Abroad', Says Manish Sisodia In Bail Hearing. CBI Opposes\xa0\xa0NDTV\r\n</li><li>Sisodia's Judicial Custody Extended Till April 3; Bail Hearing Today\xa0\xa0Republic World\r\n</li><li>Rahul Gandhi renews 'democracy under attack' charge; Court exten…",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:00:01Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': None, 'name': 'Nextpit.de'},
#    'author': 'Matthias "MaTT" Zellmer',
#    'title': 'Apple iPhone 15 Pro: So sehen wohl die neuen "Taptic Buttons" aus!',
#    'description': 'Es ist kein großes Geheimnis, dass viele Leaker davon ausgehen, dass das Apple iPhone 15 Pro (Max) mit neuen "Taptic Buttons" kommen. Hier ein erstes Bild.(Dies ist ein Teaser - klick hier, um den kompletten Beitrag zu lesen)',
#    'url': 'https://www.nextpit.de/apple-iphone-15-pro-so-sehen-wohl-die-neuen-taptic-buttons-aus',
#    'urlToImage': 'https://fscl01.fonpit.de/userfiles/7687254/image/Apple_iPhone_14_Pro_Max/NextPit_Apple_iPhone_14_Pro_Max_Side.jpg',
#    'publishedAt': '2023-03-21T11:00:01Z',
#    'content': 'So sehen vermutlich die\xa0"Taptic Buttons" des Apple iPhone 15 Pro (Max) aus\r\nBis wir die Apple-iPhone-15-Serie von Tim Cook präsentiert bekommen, werden noch sechs Monate ins Land gehen. Dennoch sind … [+2190 chars]'},
#   {'source': {'id': None, 'name': 'Tablefortwoblog.com'},
#    'author': 'Julie Chiou',
#    'title': 'Chicken Gyros',
#    'description': 'These Greek-inspired chicken gyros are packed full of marinated chicken breasts inside a warm pita with all the dressings and toppings!',
#    'url': 'https://www.tablefortwoblog.com/chicken-gyros/',
#    'urlToImage': 'https://www.tablefortwoblog.com/wp-content/uploads/2023/03/chicken-gyros-recipe-photo-tablefortwoblog-11-scaled.jpg',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'Chicken Gyros feature the most incredible marinated chicken breast meat, fresh veggies, and homemade tzatziki sauce all wrapped up in a pita! These easy to make handheld entrees are Greek in origin a… [+8093 chars]'},
#   {'source': {'id': None, 'name': 'Quartz India'},
#    'author': 'Quartz Staff',
#    'title': "How to better understand Adam Smith's invisible hand metaphor",
#    'description': 'This is the full transcript for season 4, episode 7 of the Quartz Obsession podcast on the invisible hand.Read more...',
#    'url': 'https://qz.com/invisible-hand-adam-smith-wealth-nations-1850245578',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/07323cd933b193cffeb6d52b883f416f.jpg',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'This is the full transcript for season 4, episode 7 of the Quartz Obsession podcast on the invisible hand.\r\nListen on: Apple Podcasts | Spotify | Google | Stitcher\r\nNalis: There are concepts out ther… [+16896 chars]'},
#   {'source': {'id': None, 'name': 'Quartz India'},
#    'author': 'Quartz Staff',
#    'title': "The invisible hand: Capitalism's misunderstood metaphor",
#    'description': 'What drives the global economy? Any student of economics is likely to mention the “invisible hand”—the collective self-interest that acts as the market’s guiding force in a more powerful and beneficial way than government intervention can. Legendary 18th cent…',
#    'url': 'https://qz.com/invisible-hand-economics-metaphor-adam-smith-1850245055',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ae99cbcefbcd3a9fe1d2047797e76103.png',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'What drives the global economy? Any student of economics is likely to mention the invisible handthe collective self-interest that acts as the markets guiding force in a more powerful and beneficial w… [+1520 chars]'},
#   {'source': {'id': None, 'name': 'Applesfera.com'},
#    'author': 'Isra Fdez',
#    'title': 'Apple WWDC 2023: fechas, gafas Reality Pro, iOS 17, macOS14 y todo lo que creemos saber sobre esta conferencia de desarrolladores',
#    'description': '¿Estáis tan ansiosos como nosotros? Nueva temporada, nueva estación y una nueva Apple WWDC 2023 a la vuelta de la esquina. Desde la soleada California calientan motores para sorprender a todo el mundo con la que será la conferencia para desarrolladores y pren…',
#    'url': 'https://www.applesfera.com/nuevo/apple-wwdc-2023-informacion',
#    'urlToImage': 'https://i.blogs.es/03233e/wwdc-2023/840_560.jpeg',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': '¿Estáis tan ansiosos como nosotros? Nueva temporada, nueva estación y una nueva Apple WWDC 2023 a la vuelta de la esquina. Desde la soleada California calientan motores para sorprender a todo el mund… [+10458 chars]'},
#   {'source': {'id': None, 'name': 'heise online'},
#    'author': 'Leo Becker',
#    'title': 'heise-Angebot: Webinar: Apples neue Sicherheitsfunktionen im Einsatz',
#    'description': 'Ende-zu-Ende-Verschlüsselung für iCloud, Passkeys statt Passwörter, Lockown-Modus und mehr. Das Webinar erklärt, was Unternehmen beachten müssen.',
#    'url': 'https://www.heise.de/news/Webinar-Apples-neue-Sicherheitsfunktionen-im-Einsatz-7564831.html',
#    'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/3/7/2/1/9/6/1/Deployment-Ticker-Header-16-9-eefea37526ba2e20.jpg',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'Sicherheit ist ein immer zentraleres Thema, sowohl für Unternehmen als auch Endnutzer. Entsprechend baut auch Apple die Schutzfunktionen seiner Betriebssysteme kontinuierlich aus, allein iOS 16 und m… [+1581 chars]'},
#   {'source': {'id': None, 'name': 'Modernmrsdarcy.com'},
#    'author': 'Anne Bogel',
#    'title': 'Books that change the way you see your city and your world',
#    'description': 'Today’s new episode has been a long time coming, because I’ve long been a huge fan of Jeff Speck’s work, and his book\xa0Walkable City in particular.\xa0If you’re well acquainted with […]\nThe post Books that change the way you see your city and your world appeared …',
#    'url': 'https://modernmrsdarcy.com/372-episode/',
#    'urlToImage': 'https://modernmrsdarcy.com/wp-content/uploads/2023/03/a-person-reading-a-book-while-walking.png',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': "Jeff Speck [00:00:00] That's absolutely one of my favorites. Many of my favorite books are the ones that were the most work. It is wonderful, wonderful.\r\nAnne Bogel [00:00:07] A lot of work, but the … [+53554 chars]"},
#   {'source': {'id': None, 'name': 'Mediafax.ro'},
#    'author': 'Mediafax',
#    'title': 'Cristian Andrei, fondatorul IXFI, cea mai populară platformă de tranzacţionare cripto creată în România: „Criptomonedele sunt pentru toată lumea şi ştiu că vom aduce o contribuţie importantă la adoptarea globală în următorii ani”',
#    'description': '',
#    'url': 'https://www.mediafax.ro/economic/cristian-andrei-fondatorul-ixfi-cea-populara-platforma-tranzactionare-cripto-creata-romania-criptomonedele-toata-lumea-stiu-vom-aduce-contributie-importanta-adoptarea-globala-urmatorii-ani-21715829',
#    'urlToImage': 'https://storage0.dms.mpinteractiv.ro/media/1/1/1686/21715829/1/50d25287-a42d-45de-ab1e-aac07129f1d7.jpg?width=640',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'De la lansarea de la finalul anului 2021, platforma IXFI.com a înregistrat deja un trafic de aproape 9 milioane de vizitatori unici i peste 350.000 de utilizatori activi pe platforma web, iar aplicai… [+5862 chars]'},
#   {'source': {'id': 'fortune', 'name': 'Fortune'},
#    'author': 'Leo Schwartz',
#    'title': "Sam Altman wants to give you crypto to scan your eyeballs. Can he get 8 billion people stare into a futuristic orb to prove they're not A.I. bots?",
#    'description': 'Inside the ChatGPT founder’s other venture, a crypto-powered sci-fi startup.',
#    'url': 'https://fortune.com/crypto/2023/03/21/sam-altman-orb-scan-eyeballs-ai-bot-worldcoin/',
#    'urlToImage': 'https://content.fortune.com/wp-content/uploads/2023/03/CRYPTO-WORLDCOIN-ORB-230312-KM-FORTUNE-WORLDCOIN-5403.jpg?resize=1200,600',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'The Worldcoin orb resembles a bowling ball conceived by Steve Jobs or an oversized Magic 8 ball possessed by HAL 9000. Its glossy exterior envelops the sphere, save for a gaping black circle in the f… [+12654 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Joe Tenebruso)',
#    'title': '2 Top Stocks to Buy Now That Could Be Worth $1 Trillion by 2030 or Sooner',
#    'description': 'These elite businesses are set to take their place among the most valuable companies in the world.',
#    'url': 'https://www.fool.com/investing/2023/03/21/top-stocks-to-buy-that-could-be-worth-1-trillion/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/725199/cash-gettyimages-629796418.jpg',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'Only a select few enterprises reach the exclusive $1 trillion market cap club.\xa0Those that do typically have their profit growth propelled by enduring global megatrends that enable them to deliver exc… [+4626 chars]'},
#   {'source': {'id': None, 'name': 'Independent.ie'},
#    'author': 'Myles Buchanan',
#    'title': 'Wicklow growers unite in call for community gardens',
#    'description': 'THE recent online Spring gathering and forum of Community Growers held on Saturday, March 11, saw attendees, including Dónal McCormack of Blessington Allotments, unanimously backing calls for revised legislation to require local authorities to provide allotme…',
#    'url': 'https://www.independent.ie/regionals/wicklow/news/wicklow-growers-unite-in-call-for-community-gardens-42397063.html',
#    'urlToImage': 'https://www.independent.ie/regionals/wicklow/news/3cc8a/42397062.ece/AUTOCROP/w1240h700/hoto%20November%202022.jpg',
#    'publishedAt': '2023-03-21T10:59:52Z',
#    'content': 'THE recent online Spring gathering and forum of Community Growers held on Saturday, March 11, saw attendees, including Dónal McCormack of Blessington Allotments, unanimously backing calls for revised… [+2078 chars]'},
#   {'source': {'id': None, 'name': 'Macitynet.it'},
#    'author': 'Pubblicità',
#    'title': 'Gli smartwatch KUMI (e gli occhiali Smart) sono scontati fino al 62%',
#    'description': 'In promozione il KU6 e il performante GT6 Pro: prezzi a partire da 39 €. E una sorpresa\n- su macitynet.it Gli smartwatch KUMI (e gli occhiali Smart) sono scontati fino al 62%',
#    'url': 'https://www.macitynet.it/gli-smartwatch-kumi-sono-scontati-fino-al-70/',
#    'urlToImage': 'https://www.macitynet.it/wp-content/uploads/2023/03/smartwatch-kumi-sconto-4.jpg',
#    'publishedAt': '2023-03-21T10:59:51Z',
#    'content': 'Il momento giusto per acquistare un nuovo dispositivo della linea KUMI è adesso: grazie ad una promozione infatti tre dei modelli di questo marchio sono in sconto, con risparmi che arrivano fino al 7… [+2950 chars]'},
#   {'source': {'id': None, 'name': 'Techblog.gr'},
#    'author': 'Σπύρος Τζάνης',
#    'title': 'iPhone 15: Μεγαλύτερες ταχύτητες για τους φορτιστές USB-C με πιστοποίηση MFi',
#    'description': 'Η επερχόμενη σειρά iPhone 15 της Apple θα περιλαμβάνει υποστήριξη για μεγαλύτερες ταχύτητες φόρτισης όταν χρησιμοποιείται με φορτιστές USB-C με πιστοποίηση MFi.\niPhone 15: Μεγαλύτερες ταχύτητες για τους φορτιστές USB-C με πιστοποίηση MFi - Techblog',
#    'url': 'https://techblog.gr/mobile/iphone-15-megalyteres-tachytites-toys-fortistes-usb-c-pistopoiisi-mfi/',
#    'urlToImage': 'https://techblog.gr/wp-content/uploads/2023/03/iphone-1.jpg',
#    'publishedAt': '2023-03-21T10:59:19Z',
#    'content': 'Η επερχόμενη σειρά iPhone 15 της Apple θα περιλαμβάνει υποστήριξη για μεγαλύτερες ταχύτητες φόρτισης όταν χρησιμοποιείται με φορτιστές USB-C με πιστοποίηση MFi, σύμφωνα με το τελευταίο ερευνητικό σημ… [+1693 chars]'},
#   {'source': {'id': None, 'name': 'Ferra.ru'},
#    'author': 'Ксения Мурашева',
#    'title': 'Apple снизила свою зависимость от Samsung в серии iPhone 14',
#    'description': 'Apple и Samsung — заклятые друзья. Первая компания использует компоненты, изготовленные второй, при этом они приходятся друг другу самыми серьёзными конкурентами на рынке смартфонов. Впрочем, как сообщают источники, Apple стремится уменьшить свою зависимость …',
#    'url': 'https://www.ferra.ru/news/mobile/apple-snizila-svoyu-zavisimost-ot-samsung-v-serii-iphone-14-21-03-2023.htm',
#    'urlToImage': 'https://www.ferra.ru/imgs/2023/03/21/10/5842369/f15dc54d7d1fba30f299b86f4c04b0099e6453da.jpg',
#    'publishedAt': '2023-03-21T10:59:18Z',
#    'content': ', Apple LG Display OLED-, Samsung Display iPhone 14 Pro Max. Samsung OLED- Apple, , iPhone 12 Pro iPhone 12 Pro Max. BOE LG Display. , Samsung Display OLED- Apple.\r\n , Apple Watch Ultra Apple MicroLE… [+5 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'Jan Dams',
#    'title': 'Wir erleben das Ende der souveränen Schweiz',
#    'description': 'Seit jeher gilt die Schweiz als Hort von Sicherheit und Eigenständigkeit. Mit der Zwangsfusion von UBS und Credit Suisse gibt sie diese Freiheit in die Hände von Bankern. Im Notfall sind die Eidgenossen ab jetzt auf Hilfe aus dem Ausland angewiesen und riskie…',
#    'url': 'https://www.welt.de/wirtschaft/article244401096/Bankenkrise-Wir-erleben-das-Ende-der-souveraenen-Schweiz.html',
#    'urlToImage': 'https://img.welt.de/img/wirtschaft/mobile244403774/7931352467-ci16x9-w1200/kombo-jan-dams-ubs.jpg',
#    'publishedAt': '2023-03-21T10:58:44Z',
#    'content': 'Seit 175 Jahren existiert die Schweiz in ihrer jetzigen Form. Unser Bild des Landes ist geprägt von zwei Dingen: Zum Ersten von großem Wohlstand das Pro-Kopf-Vermögen der Schweizer lag im Schnitt bei… [+3032 chars]'},
#   {'source': {'id': None, 'name': 'Iphon.fr'},
#    'author': 'Jean-Yves Alric',
#    'title': 'Devinez combien coûte cet autographe de Steve Jobs',
#    'description': 'Cet objet de collection signé par Steve Jobs n’est clairement pas à la portée de toutes les bourses.',
#    'url': 'https://www.iphon.fr/post/devinez-combien-coute-cet-autographe-de-steve-jobs',
#    'urlToImage': 'https://www.iphon.fr/app/uploads/2020/01/steve-jobs-ipad.jpg',
#    'publishedAt': '2023-03-21T10:57:14Z',
#    'content': 'On a pris lhabitude de voir les objets liés à Steve Jobs sarracher comme des petits pains. Cest cette fois une plaque de récompense remise à une employée dApple en l’an 2000 et signée de la main du d… [+1686 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'iPhone 14 report confirms Apple was right to kill the iPhone 13 mini - TechRadar',
#    'description': '<ol><li>iPhone 14 report confirms Apple was right to kill the iPhone 13 mini\xa0\xa0TechRadar\r\n</li><li>Report Suggests iPhone 14 Plus More Popular Than iPhone 13 Mini\xa0\xa0MacRumors\r\n</li><li>Apple iPhone 14 Plus Sales Trump iPhone 13 Mini as per Latest Reports\xa0\xa0gizmo…',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiY2h0dHBzOi8vd3d3LnRlY2hyYWRhci5jb20vbmV3cy9pcGhvbmUtMTQtcmVwb3J0LWNvbmZpcm1zLWFwcGxlLXdhcy1yaWdodC10by1raWxsLXRoZS1pcGhvbmUtMTMtbWluadIBAA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T10:56:41Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'techradar', 'name': 'TechRadar'},
#    'author': 'James Rogerson',
#    'title': 'iPhone 14 report confirms Apple was right to kill the iPhone 13 mini',
#    'description': 'Panel shipments for the iPhone 14 Plus are dramatically higher than they were for the 13 mini. Apple made the right call, it seems?',
#    'url': 'https://www.techradar.com/news/iphone-14-report-confirms-apple-was-right-to-kill-the-iphone-13-mini',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/fkWsDJcDRULGUTbFKCSPt5-1200-80.jpg',
#    'publishedAt': '2023-03-21T10:56:41Z',
#    'content': 'The iPhone mini line only lasted two generations. There was an iPhone 12 mini followed by an iPhone 13 mini, but then Apple went in the opposite direction and launched a larger iPhone 14 Plus, instea… [+2584 chars]'},
#   {'source': {'id': None, 'name': '9to5Toys'},
#    'author': 'Rikka Altland',
#    'title': 'Apple’s latest 12.9-inch M2 iPad Pro is now $200 off',
#    'description': 'Amazon is now offering one of the first chances to save on Apple’s newest 12.9-inch M2 iPad Pro. Discounting the Wi-Fi 512GB capacity to a new all-time low, you can now drop this flagship device to $1,199 shipped. That’s down from the usual $1,399 going rate …',
#    'url': 'https://9to5toys.com/2023/03/21/12-9-inch-m2-ipad-pro-512gb-sale/',
#    'urlToImage': 'https://i0.wp.com/9to5toys.com/wp-content/uploads/sites/5/2022/11/12.9-inch-m2-ipad-pro.png?resize=1200%2C628&ssl=1',
#    'publishedAt': '2023-03-21T10:55:00Z',
#    'content': 'Amazon is now offering one of the first chances to save on Apples newest 12.9-inch M2 iPad Pro. Discounting the Wi-Fi 512GB capacity to a new all-time low, you can now drop this flagship device to $1… [+2178 chars]'},
#   {'source': {'id': None, 'name': 'Smzdm.com'},
#    'author': None,
#    'title': '百亿补贴：Apple 苹果 iPhone 14 Pro Max 5G智能手机 128GB 8399元包邮（需用券）',
#    'description': '拼多多品牌好货此款目前百亿补贴售价8599元，页面领取200优惠券实付8399元包邮，近期好价。',
#    'url': 'https://www.smzdm.com/p/75584452/',
#    'urlToImage': 'https://y.zdmimg.com/202209/08/631958985ea686277.jpg_d250.jpg',
#    'publishedAt': '2023-03-21T10:54:41Z',
#    'content': 'iPhone 14 Pro Max 6.72796*1290460PPIApp1000HDR16002000 ProMotion Super Retina XDR 1 Hz120 HzAlways-On\r\niPhone 14 ProA164nm160 6 CPU A1520%A16 Bionic 5 GPU 50% 16 17 iPhone 14 Pro Max 29iPhone 14\r\niPh… [+51 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'PlayStation VR2 bei Media Markt kaufen: Hol dir jetzt die neue PS5-Brille - TVMovie.de',
#    'description': '<ol><li>PlayStation VR2 bei Media Markt kaufen: Hol dir jetzt die neue PS5-Brille\xa0\xa0TVMovie.de\r\n</li><li>9 fantastische VR-Spiele, die Sony unbedingt auf PSVR 2 holen sollte\xa0\xa0GamePro\r\n</li><li>Warum euch mit PSVR 2 eher übel werden könnte als mit anderen VR-Br…',
#    'url': 'https://consent.google.com/ml?continue=https://news.google.?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T10:54:37Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': None, 'name': 'Hdblog.it'},
#    'author': 'HDblog.it',
#    'title': 'Exynos Connect 100 ufficiale: il primo chip UWB proprietario Samsung',
#    'description': 'Debutta anche il brand Exynos Connect, che si occuperà di tutti i chip di connettività a corto raggio come Wi-Fi e Bluetooth.',
#    'url': 'https://www.hdblog.it/hardware/articoli/n567829/samsung-exynos-connect-100-chip-uwb-proprietario/',
#    'urlToImage': 'https://hd2.tudocdn.net/1087252?w=1920',
#    'publishedAt': '2023-03-21T10:52:00Z',
#    'content': 'Samsung ha presentato il suo primo chip UWB, destinato a smartphone, tablet, indossabili, veicoli e tanto altro: si chiama Exynos Connect 100, e con esso debutta anche il brand Exynos Connect, sotto … [+1679 chars]'},
#   {'source': {'id': None, 'name': 'Filmomaniak.pl'},
#    'author': 'Jan Tracz',
#    'title': 'Warto nadrobić Teda Lasso, to obecnie jeden z najlepszych seriali',
#    'description': 'Ted Lasso to jeden z najbardziej udanych seriali kilku ostatnich lat. Produkcja wkracza właśnie w ostatni sezon, więc to doskonały moment, aby zapoznać się z tym nie-do-końca-popularnym-w-Polsce komediodramatem.\r\nInformacja Warto nadrobić Teda Lasso, to obecn…',
#    'url': 'https://filmomaniak.pl/newsroom/warto-nadrobic-teda-lasso-to-obecnie-jeden-z-najlepszych-seriali/z824729',
#    'urlToImage': 'https://www.gry-online.pl/i/h/22/417095466.jpg',
#    'publishedAt': '2023-03-21T10:51:11Z',
#    'content': 'Wiadomofilmy i seriale21 marca 2023, 11:51\r\nTed Lasso to jeden z najbardziej udanych seriali kilku ostatnich lat. Produkcja wkracza wanie w ostatni sezon, wic to doskonay moment, aby zapozna si z tym… [+8663 chars]'},
#   {'source': {'id': None, 'name': 'Trendhunter.com'},
#    'author': None,
#    'title': 'Aesthetically-Pleasing Computer Peripherals - Fabio Verdelli Design Studio’s DUNE Mouse is Stunning (TrendHunter.com)',
#    'description': '(TrendHunter.com) The DUNE mouse by Fabio Verdelli Design Studio is one of the most striking examples of sculptural computer peripheries. Since much of the focus when designing tools like this falls on increasing...',
#    'url': 'https://www.trendhunter.com/trends/dune-mouse',
#    'urlToImage': 'https://cdn.trendhunterstatic.com/thumbs/501/dune-mouse.jpeg?auto=webp',
#    'publishedAt': '2023-03-21T10:50:02Z',
#    'content': 'The DUNE mouse by Fabio Verdelli Design Studio is one of the most striking examples of sculptural computer peripheries. Since much of the focus when designing tools like this falls on increasing func… [+615 chars]'},
#   {'source': {'id': None, 'name': 'TheGrio'},
#    'author': 'Associated Press',
#    'title': 'Pay transparency is spreading, and that’s good for Black workers',
#    'description': 'NEW YORK (AP) — U.S. employers are increasingly posting salary ranges for job openings, even in states where it’s not\nThe post Pay transparency is spreading, and that’s good for Black workers appeared first on TheGrio.',
#    'url': 'http://thegrio.com/2023/03/21/pay-transparency-is-spreading-and-thats-good-for-black-workers/',
#    'urlToImage': 'https://thegrio.com/wp-content/uploads/2023/03/AP23074661240413-scaled.jpg',
#    'publishedAt': '2023-03-21T10:50:00Z',
#    'content': 'Black women make just 64 cents for every $1 paid to white men.\r\nNEW YORK (AP) U.S. employers are increasingly posting salary ranges for job openings, even in states where its not required by law, acc… [+7129 chars]'},
#   {'source': {'id': None, 'name': 'Cossa.ru'},
#    'author': None,
#    'title': 'PR-директор AGIMA Кристина Ляпцева: «Не всем диджитал-агентствам нужен PR»',
#    'description': 'Как грамотно организовать PR\xa0диджитал-агентства и\xa0что должен уметь крепкий PR-специалист.',
#    'url': 'https://www.cossa.ru/211/319284/',
#    'urlToImage': 'http://www.cossa.ru/upload/iblock/aa6/1200.jpg',
#    'publishedAt': '2023-03-21T10:49:00Z',
#    'content': '5 PR- AGIMA. \xa0 \xa0 , \xa0 50 . \xa0\xa0 2022- 1\xa0\xa0, \xa0 1,5\xa0. AGIMA \xa0 \xa0 .\r\n\xa0\xa0 \xa0- . \xa0 AGIMA, \xa0\xa0 \xa0\xa0\xa0 \xa0 10 \xa0 \xa0. \xa0 \xa0 \xa0, PR\xa0- \xa0 PR-.\r\n« PR\xa0\xa0 » \r\n \xa0 , \xa0 \xa0, \xa0 \xa0PR. , , \xa0. \xa0, PR\xa0 \xa0.\r\n, :\r\n , : SMS MMS-, , , e-mail-!\r\n\xa0 \xa0 … [+2844 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'WELT',
#    'title': 'Bundesregierung rechnet mit Verbrenner-Einigung bis Donnerstag',
#    'description': 'Insbesondere die FDP drängt darauf, dass auch nach 2035 noch Neuwagen mit Verbrenner zugelassen werden dürfen, die klimaneutrale E-Fuels tanken. Laut Europa-Staatsministerin Anna Lührmann (Grüne) sei mit einer zeitnahen Einigung im Streit um das Verbrenner-Au…',
#    'url': 'https://www.welt.de/politik/deutschland/article244403328/EU-Gipfel-Bundesregierung-rechnet-mit-Verbrenner-Einigung-bis-Donnerstag.html',
#    'urlToImage': 'https://img.welt.de/img/politik/deutschland/mobile244403326/4971353527-ci16x9-w1200/E-Fuels.jpg',
#    'publishedAt': '2023-03-21T10:48:54Z',
#    'content': 'Die Bundesregierung rechnet mit einer raschen Lösung im Streit über das Aus für neue Autos mit Verbrennungsmotor in der EU.\r\nEuropa-Staatsministerin Anna Lührmann (Grüne) sagte am Dienstag in Brüssel… [+2391 chars]'},
#   {'source': {'id': None, 'name': 'iGeneration'},
#    'author': 'Nicolas Furno',
#    'title': 'Le premium a représenté pour la première fois plus de la moitié des revenus sur le marché des smartphones',
#    'description': 'La crise économique mondiale a aidé le segment du premium sur le marché des smartphones, d’après les analyses publiées par Counterpoint. Selon la firme, le marché du smartphone a baissé dans son ensemble en 2022, mais la baisse de l’ordre de 1\xa0% des ventes n’…',
#    'url': 'https://www.igen.fr/iphone/2023/03/le-premium-represente-pour-la-premiere-fois-plus-de-la-moitie-des-revenus-sur-le-marche-des-smartphones-136195',
#    'urlToImage': 'https://cdn.mgig.fr/2023/03/mga-5995474f-w375-w1500-w750_accroche.jpg',
#    'publishedAt': '2023-03-21T10:48:22Z',
#    'content': 'La crise économique mondiale a aidé le segment du premium sur le marché des smartphones, daprès les analyses publiées par Counterpoint. Selon la firme, le marché du smartphone a baissé dans son ensem… [+2614 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'WELT',
#    'title': 'Urteil zu illegalen Abschalteinrichtungen – Diesel-Käufer können jetzt Schadenersatz fordern',
#    'description': 'Wer ein Auto mit einer unzulässigen Abschalteinrichtung gekauft hat, der kann Schadenersatz fordern. Das entschied der Europäische Gerichtshof. Die Autobauer haften auch, wenn sie nur fahrlässig gehandelt haben. Es ging in dem Verfahren um eine Klage gegen Me…',
#    'url': 'https://www.welt.de/wirtschaft/article244402238/EuGH-Urteil-im-Dieselskandal-Kaeufer-koennen-jetzt-Schadenersatz-fordern.html',
#    'urlToImage': 'https://img.welt.de/img/wirtschaft/mobile244402236/9771357477-ci16x9-w1200/EuGH.jpg',
#    'publishedAt': '2023-03-21T10:48:00Z',
#    'content': 'Autokäufer können gegenüber dem Hersteller einen Anspruch auf Schadenersatz haben, wenn ihnen wegen einer im Fahrzeug verbauten unzulässigen Abschalteinrichtung ein Schaden entstanden ist. Das EU-Rec… [+3011 chars]'},
#   {'source': {'id': None, 'name': 'Imagazine.pl'},
#    'author': 'Krzysztof Kołacz',
#    'title': 'Rosja zaczyna banować Apple',
#    'description': 'Ostatnio Apple poinformowało o wstrzymaniu świadczenia wsparcia serwisowego dla Rosji. Na odpowiedź nie czekaliśmy długo. W ramach przygotowań do nadchodzących wyborów prezydenckich w Rosji Kreml zabronił urzędnikom państwowym korzystania z iPhone’ów. Według …',
#    'url': 'https://imagazine.pl/2023/03/21/rosja-zaczyna-banowac-apple/',
#    'urlToImage': 'https://imagazine.pl/wp-content/uploads/2023/03/AppleWatch-Rosja.png',
#    'publishedAt': '2023-03-21T10:47:16Z',
#    'content': 'Ostatnio Apple poinformowao o\xa0wstrzymaniu wiadczenia wsparcia serwisowego dla Rosji. Na\xa0odpowied nie\xa0czekalimy dugo.\r\nW\xa0ramach przygotowa do\xa0nadchodzcych wyborów prezydenckich w\xa0Rosji Kreml zabroni u… [+478 chars]'},
#   {'source': {'id': None, 'name': 'Genbeta.com'},
#    'author': 'Bárbara Bécares',
#    'title': 'La lección que Steve Jobs y su "hippie desaliñado" dan a recursos humanos: así perdió Apple a un genio de la programación',
#    'description': 'A menudo en Genbeta analizamos la labor de Recursos Humanos a la hora de escoger profesionales entre la larga lista de candidaturas que pueden llegar a recibir para una posición para sacar el mejor partido a sus empresas. Al mismo tiempo, también vemos cómo t…',
#    'url': 'https://www.genbeta.com/desarrollo/leccion-que-steve-jobs-su-hippie-desalinado-dan-a-recursos-humanos-asi-perdio-apple-a-genio-programacion',
#    'urlToImage': 'https://i.blogs.es/51e255/md-mahdi-xf33zlb6fkw-unsplash/840_560.jpeg',
#    'publishedAt': '2023-03-21T10:45:39Z',
#    'content': 'A menudo en Genbeta analizamos la labor de Recursos Humanos a la hora de escoger profesionales entre la larga lista de candidaturas que pueden llegar a recibir para una posición para sacar el mejor p… [+4064 chars]'},
#   {'source': {'id': None, 'name': 'Sapo.pt'},
#    'author': 'Pedro Simões',
#    'title': 'A Microsoft quer criar a sua loja de jogos e apps para o Android e o iOS',
#    'description': 'As medidas que a União Europeia prevê aplicar no Android e no iOS podem abrir caminho para algumas novidades da Microsoft. Ao obrigar à presença de outras lojas de apps, cria um novo mercado...',
#    'url': 'https://pplware.sapo.pt/smartphones-tablets/a-microsoft-quer-criar-a-sua-loja-de-apps-para-o-android-e-o-ios/',
#    'urlToImage': 'https://pplware.sapo.pt/wp-content/uploads/2023/03/loja_ms_android_ios_1.jpg',
#    'publishedAt': '2023-03-21T10:45:08Z',
#    'content': 'As medidas que a União Europeia prevê aplicar no Android e no iOS podem abrir caminho para algumas novidades da Microsoft. Ao obrigar à presença de outras lojas de apps, cria um novo mercado que a gi… [+1998 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'WELT',
#    'title': 'Städte- und Gemeindebund empfiehlt Umzug aufs Land',
#    'description': 'Die Wohnungsnot in den Metropolen wächst. In ländlichen Gegenden stehen hingegen 1,3 Millionen Wohnungen leer, die man laut Städte- und Gemeindebund besser nutzen sollte. Das sei preiswerter und für Viele mit Homeoffice umsetzbar.',
#    'url': 'https://www.welt.de/wirtschaft/article244402140/Wohnungsnot-Staedte-und-Gemeindebund-empfiehlt-Staedtern-Umzug-aufs-Land.html',
#    'urlToImage': 'https://img.welt.de/img/regionales/hamburg/mobile225614913/6811351177-ci16x9-w1200/Neubauten-auf-der-gruenen-Wiese.jpg',
#    'publishedAt': '2023-03-21T10:45:00Z',
#    'content': 'Der Städte- und Gemeindebund hat angesichts der Wohnungsnot in den Metropolen dazu aufgerufen, Wohnungen auf dem Land zu nutzen. Es werde kaum beachtet, dass über 1,3 Millionen marktfähige Wohnungen,… [+1309 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'WELT',
#    'title': 'Bundesbauministerin empfiehlt Umzug aufs Land',
#    'description': 'Die Wohnungsnot in den Metropolen wächst. Bundesbauministerin Klara Geywitz will mehr Menschen zum Umzug aufs Land bewegen. Auch der Städte- und Gemeindebund appelliert: In ländlichen Regionen zu wohnen, sei preiswerter und für Viele mit Homeoffice umsetzbar.',
#    'url': 'https://www.welt.de/wirtschaft/article244402140/Wohnungsnot-Bundesbauministerin-empfiehlt-Staedtern-Umzug-aufs-Land.html',
#    'urlToImage': 'https://img.welt.de/img/regionales/hamburg/mobile225614913/6811351177-ci16x9-w1200/Neubauten-auf-der-gruenen-Wiese.jpg',
#    'publishedAt': '2023-03-21T10:45:00Z',
#    'content': 'Um die Wohnungsnot in den Städten zu lindern, will Bundesbauministerin Klara Geywitz mehr Menschen zum Umzug aufs Land bewegen. In Deutschland gibt es schätzungsweise 1,7 Millionen leer stehende Wohn… [+2365 chars]'},
#   {'source': {'id': None, 'name': 'netzwelt'},
#    'author': 'Michael Knott',
#    'title': 'iPhone 15 Pro: So sehen die neuen Smart-Tasten aus',
#    'description': 'Apples iPhone 15 Pro und iPhone 15 Pro Max werden mit einer gravierenden Änderung erscheinen. Neu gestaltete Tasten sollen mit Gewohntem brechen.\nDieser Artikel wurde einsortiert unter \nApple,Technology,iPhone 15: Gerüchte, Release, Technik, Preis - was wir b…',
#    'url': 'https://www.netzwelt.de/news/215473-iphone-15-leak-so-sehen-neuen-smart-tasten.html',
#    'urlToImage': 'https://img.netzwelt.de/dw1600_dh900_sw1648_sh927_sx8_sy2_sr16x9_nu2/picture/original/2023/03/iphone-15-pro-iphone-15-pro-max-neuen-tasten-erscheinen-366375.jpeg',
#    'publishedAt': '2023-03-21T10:43:19Z',
# ...
#    'url': 'https://news.yahoo.com/asked-chatgpt-where-invest-10-102316898.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/_Kas1S5M69uvnhHDUZ36xg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03NTA-/https://media.zenfs.com/en/the_telegraph_258/e005688f1ae63df033dfb3513df29b98',
#    'publishedAt': '2023-03-21T10:23:16Z',
#    'content': 'ChatGPT logo and rising stock graph are seen in this illustration - REUTERS/Dado Ruvic/Illustration/File Photo\r\nIn February I asked ChatGPT to invest for me and make a portfolio to grow my savings.\r\n… [+4078 chars]'},
#   {'source': {'id': None, 'name': 'Elchapuzasinformatico.com'},
#    'author': 'Protector Indefinido',
#    'title': 'Google Pixel 8 Pro, nuevos detalles de diseño: pantalla plana y bíseles curvos',
#    'description': 'Nuevos e interesantes detalles de lo que será el buque insignia de Google para competir con su gran rival, Apple. Y es que este Pixel 8 Pro quiere desbancar en la medida de lo posible al nuevo iPhone 15 Pro que está por salir y para ello no solamente va a met…',
#    'url': 'https://elchapuzasinformatico.com/2023/03/google-pixel-8-pro-diseno-pantalla-plana-biseles-curvos/',
#    'urlToImage': 'https://elchapuzasinformatico.com/wp-content/uploads/2023/03/Google-Pixel-8-y-Pixel-8-Pro.jpg',
#    'publishedAt': '2023-03-21T10:23:05Z',
#    'content': 'Nuevos e interesantes detalles de lo que será el buque insignia de Google para competir con su gran rival, Apple. Y es que este Pixel 8 Pro quiere desbancar en la medida de lo posible al nuevo iPhone… [+3152 chars]'},
#   {'source': {'id': None, 'name': 'Kanobu.ru'},
#    'author': 'lianveta',
#    'title': 'Риз Уизерспун спродюсирует фильм в\xa0духе «День сурка» для Apple Studios',
#    'description': 'Apple Studios совместно с компанией Hello Sunshine Риз Уизерспун экранизируют роман Maybe Next Time за авторством Чески Мейджор — об этом пишет издание Deadline. Уизерспун выступит одним из продюсеров будущего фильма, который пополнит линейку Apple Original F…',
#    'url': 'https://kanobu.ru/news/riz-uizerspun-sprodyusiruet-film-v-duhe-den-surka-dlya-apple-studios-465273/',
#    'urlToImage': 'https://cdn.kanobu.ru/articles/pics/tmp/images/2023/3/21/71e82337-7b9b-1b5f-2bbb-ec8ba3dfb971.jpg',
#    'publishedAt': '2023-03-21T10:22:03Z',
#    'content': 'Apple Studios Hello Sunshine Maybe Next Time Deadline. , Apple Original Film.\r\n , , . - : . , , , . , , . . Maybe Next Time 7 .\r\n Hello Sunshine Apple Studios «, » (The Last Thing He Told Me), Apple … [+33 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'Alexander Dinger, Lennart Pfahler',
#    'title': 'Inside „Letzte Generation“ – wie kompromisslos sind die Klima-Aktivisten?',
#    'description': 'Im Kampf für das Klima riskiert die „Letzte Generation“ sogar Gefängnisstrafen. Im Podcast machen sich WELT-Reporter Lennart Pfahler und Alexander Dinger auf die Suche nach den Vordenkern. Sie wollen wissen, wie die Organisation im Inneren tickt – und wie ihr…',
#    'url': 'https://www.welt.de/podcasts/dicht-dran/article244377877/Inside-Letzte-Generation-wie-kompromisslos-sind-die-Klima-Aktivisten-Podcast.html',
#    'urlToImage': 'https://img.welt.de/img/podcasts/dicht-dran/mobile244377885/5151358147-ci16x9-w1200/Polizisten-tragen-ein-Mitglied-der-Letzten-Generation-von-der-Strasse.jpg',
#    'publishedAt': '2023-03-21T10:22:00Z',
#    'content': 'Im ersten Teil des Podcasts treffen Lennart Pfahler und Alexander Dinger eine der bekanntesten Aktivistinnen der Letzten Generation. Außerdem stoßen sie auf insgesamt sechs Gigabite Dokumente, in den… [+1151 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Adam Oram',
#    'title': "Apple's AirTag Trackers Return to 2023 Low Prices at Amazon - CNET",
#    'description': 'Score a four-pack of Apple item trackers at close to 10% off and keep tabs on your valuables.',
#    'url': 'https://www.cnet.com/deals/apples-airtag-trackers-return-to-2023-low-prices-at-amazon/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/a954b1873bb53030f2ce808c5d4ced4fd2eeb10b/hub/2023/03/21/90c4a2ff-41f6-450a-8611-a28ccac60e1f/apple-airtag-4-pack.png?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2023-03-21T10:22:00Z',
#    'content': "If you're often misplacing your keys, bag, wallet or other valuable item, an AirTag tracker is a worthwhile investment. The diminutive item trackers can easily be dropped into a bag pocket or attache… [+1553 chars]"},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'WELT',
#    'title': 'Manchmal auf Deutsch, immer per Sie – Scholz gibt Einblicke in Telefonate mit Putin',
#    'description': 'Für die einen passieren sie zu häufig, für andere nicht oft genug: die Telefonate von Bundeskanzler Olaf Scholz mit Russlands Präsident Wladimir Putin. Bei einer Veranstaltung berichtete Scholz nun über die Gespräche und verriet wie sie zustande kommen.',
#    'url': 'https://www.welt.de/politik/ausland/article244400628/Scholz-und-Putin-Einblicke-in-ihre-Telefonate-manchmal-auf-Deutsch-immer-per-Sie.html',
#    'urlToImage': 'https://img.welt.de/img/politik/ausland/mobile244289601/6431355717-ci16x9-w1200/Lateinamerika-Reise-von-Bundeskanzler-Scholz.jpg',
#    'publishedAt': '2023-03-21T10:21:00Z',
#    'content': 'Bundeskanzler Olaf Scholz hat Einblicke in seine Telefonate mit dem russischen Präsidenten Wladimir Putin gegeben. Diese Gespräche seien bis zu eineinhalb Stunden lang, berichtete der SPD-Politiker a… [+2687 chars]'},
#   {'source': {'id': 'politico', 'name': 'Politico'},
#    'author': 'By Ryan Lizza, Rachael Bade and Eugene Daniels',
#    'title': "Unpacking Alvin Bragg's case against Trump",
#    'description': 'And Biden issued the first veto of his presidency yesterday.',
#    'url': 'https://www.politico.com/newsletters/playbook/2023/03/21/unpacking-alvin-braggs-case-against-trump-00088035',
#    'urlToImage': 'https://static.politico.com/1b/81/f218a05341f9923e15a6d3ba37cd/20230320-trump-indictment-police-media-wes-parnell-0003-edit.jpg',
#    'publishedAt': '2023-03-21T10:20:40Z',
#    'content': 'With help from Eli Okun and Garrett Ross\r\nWhile we dont know for sure what crime that Manhattan DA Alvin Bragg will allege, the weight of available evidence suggests Donald Trump will be charged with… [+24112 chars]'},
#   {'source': {'id': None, 'name': 'Ozbargain.com.au'},
#    'author': 'b3au',
#    'title': '[iOS] $15 off for New Customers, $5 off for Existing When You Pay with Apple Pay (Min Order $30) @ Menulog (App)',
#    'description': 'New Menulog customers get $15 off (minimum spend $30) when using Apple Pay in the app.\nGet coupon here - https://offers.menulog.com.au/new-customer-apple-pay-offer/\n\nExisting Menulog customers get $5 off (minimum spend $30) when using Apple Pay in the app.\nGe…',
#    'url': 'https://www.ozbargain.com.au/node/764001',
#    'urlToImage': 'https://www.ozbargain.com.au/themes/ozbargain/logo-square.png',
#    'publishedAt': '2023-03-21T10:19:30Z',
#    'content': 'Terms &amp; Conditions\r\nNew to Menulog customers: Get $15 off your first order when you use Apple Pay in the Menulog iOS app. Minimum spend of $30 required, excluding Service Fees. Delivery fee appli… [+1456 chars]'},
#   {'source': {'id': None, 'name': 'Contentmarketinginstitute.com'},
#    'author': 'Robert Rose',
#    'title': 'Why Remarkable Content Originates From an Unremarkable Process',
#    'description': 'Robert Rose challenges the thinking of Steve Jobs. Can you strike remarkable content without an unremarkable process?',
#    'url': 'https://contentmarketinginstitute.com/articles/remarkable-content-process-debate',
#    'urlToImage': 'https://contentmarketinginstitute.com/wp-content/uploads/2023/03/remarkable-content-debate.png',
#    'publishedAt': '2023-03-21T10:19:16Z',
#    'content': 'Comedian David Mitchell once offered this truth\xa0on the British game show Would I Lie To You?:\r\nOne of the codes I live my life by is that my appearance should be in no way noteworthy. But then again,… [+6909 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'deadline.com',
#    'title': 'Series Mania Kicks Off With ‘The Power’, ‘Drops Of God’ & ‘Haven Of Grace’ In Competition',
#    'description': 'Lille’s Series Mania Forum is kicking off today with a packed schedule of talks, screenings and competitions. Fighting it out in International Competition are the likes of Prime Video’s Toni Collette starrer The Power, Haven of Grace from Magnetic Beats direc…',
#    'url': 'https://biztoc.com/x/0e7dc304737b5276',
#    'urlToImage': 'https://c.biztoc.com/p/0e7dc304737b5276/og.webp',
#    'publishedAt': '2023-03-21T10:18:09Z',
#    'content': 'Lilles Series Mania Forum is kicking off today with a packed schedule of talks, screenings and competitions.Fighting it out in International Competition are the likes of Prime Videos Toni Collette st… [+312 chars]'},
#   {'source': {'id': None, 'name': 'COMPUTER BILD'},
#    'author': 'Manuel Bauer',
#    'title': 'iPhone 15 Pro: Bilder zeigen komplett neue Knöpfe',
#    'description': 'Schon seit Monaten kursieren Gerüchte darüber, dass Apple die mechanischen Knöpfe des iPhone 15 Pro durch Sensortasten ersetzen könnte. Neue Renderbilder scheinen das zu bestätigen – und geben Grund zur Sorge.',
#    'url': 'https://www.computerbild.de/artikel/cb-News-Handy-iPhone-15-Pro-Bilder-zeigen-komplett-neue-Knoepfe-35392481.html',
#    'urlToImage': 'https://i.computer-bild.de/imgs/1/4/8/0/4/3/1/7/1-f4044147a84dc727.jpg',
#    'publishedAt': '2023-03-21T10:18:00Z',
#    'content': 'Schon seit Monaten kursieren Gerüchte darüber, dass Apple die mechanischen Knöpfe des iPhone 15 Pro durch Sensortasten ersetzen könnte. Neue Renderbilder scheinen das zu bestätigen und geben Grund zu… [+2039 chars]'},
#   {'source': {'id': None, 'name': 'PCMag.com'},
#    'author': 'Matthew Humphries',
#    'title': 'Russian Government Tells Employees to Throw Away Their iPhones by April 1',
#    'description': "The Kremlin believes Apple's smartphones are vulnerable to hacking and espionage.\nThe Kremlin has decided iPhones are no longer safe to use by anyone who works within the Russian government.According to Russian newspaper Kommersant, Sergei Kiriyenko, Russia's…",
#    'url': 'https://uk.pcmag.com/mobile-phones/146013/russian-government-tells-employees-to-throw-away-their-iphones-by-april-1',
#    'urlToImage': 'https://sm.pcmag.com/t/pcmag_uk/news/r/russian-go/russian-government-tells-employees-to-throw-away-their-iphon_pvg1.1200.jpg',
#    'publishedAt': '2023-03-21T10:17:11Z',
#    'content': "The Kremlin has decided iPhones are no longer safe to use by anyone who works within the Russian government.\r\nAccording to Russian newspaper Kommersant, Sergei Kiriyenko, Russia's first deputy chief … [+1584 chars]"},
#   {'source': {'id': None, 'name': 'PCMag.com'},
#    'author': 'Matthew Humphries',
#    'title': 'Russian Government Tells Employees to Throw Away Their iPhones by April 1',
#    'description': "The Kremlin believes Apple's smartphones are vulnerable to hacking and espionage.\nThe Kremlin has decided iPhones are no longer safe to use by anyone who works within the Russian government.According to Russian newspaper Kommersant, Sergei Kiriyenko, Russia's…",
#    'url': 'https://me.pcmag.com/en/mobile-phones/15613/russian-government-tells-employees-to-throw-away-their-iphones-by-april-1',
#    'urlToImage': 'https://sm.pcmag.com/t/pcmag_me/news/r/russian-go/russian-government-tells-employees-to-throw-away-their-iphon_8cya.1200.jpg',
#    'publishedAt': '2023-03-21T10:17:11Z',
#    'content': "The Kremlin has decided iPhones are no longer safe to use by anyone who works within the Russian government.\r\nAccording to Russian newspaper Kommersant, Sergei Kiriyenko, Russia's first deputy chief … [+1584 chars]"},
#   {'source': {'id': None, 'name': 'Sostav.ru'},
#    'author': 'Sostav.ru',
#    'title': 'Quiet Media: чем заменить cookies и как реализовать кросс-медийную атрибуцию',
#    'description': 'Команда компании поделилась практическим опытом запуска Stable ID на платформе AdRiver',
#    'url': 'https://www.sostav.ru/publication/quiet-media-zapusk-stable-id-na-platforme-adriver-59442.html',
#    'urlToImage': 'https://www.sostav.ru/images/news/2023/03/15/preview/59442_social.jpg?rnd=661816',
#    'publishedAt': '2023-03-21T10:17:00Z',
#    'content': '- \xa0third-party cookies. «»- , \xa0 , . \xa0 Stable\xa0ID. AdTech- Quiet Media \xa0- \xa0 AdRiver \xa0 Stable\xa0ID. \xa0 , Sostav .\r\nthird-party cookies \xa0 . - , \xa0 , . , , \xa0 , cookies. \xa0 ID, \xa0\xa0 \xa0— .\r\n\xa0 , «», : IDFA\xa0— \xa0 \xa0 iOS… [+1447 chars]'},
#   {'source': {'id': None, 'name': 'Mirror Online'},
#    'author': 'mirrornews@mirror.co.uk (Alice Peacock)',
#    'title': "GB boxer dies suddenly age 19 as tributes pour in for 'future world champion'",
#    'description': "We'll be bringing you the very latest updates, pictures and video on this breaking news story",
#    'url': 'https://www.mirror.co.uk/news/uk-news/breaking-gb-boxer-dies-suddenly-29511275',
#    'urlToImage': 'https://i2-prod.mirror.co.uk/incoming/article29511272.ece/ALTERNATES/s1200/0_MAP_CHP_210323Jude-Moore_11335Jude-Moore.jpg',
#    'publishedAt': '2023-03-21T10:15:55Z',
#    'content': 'A GB boxer dubbed a "future world champion" has died suddenly, aged 19.\r\nThe family of Jude Moore, from Bristol, confirmed the nexpected passing of the "uniquely talented fighter" who was tragically … [+1756 chars]'},
#   {'source': {'id': None, 'name': 'Forrester.com'},
#    'author': 'David Truog',
#    'title': 'Generative AI Gets An Upgrade To Business Class With Adobe Firefly',
#    'description': "Adobe’s new Firefly service is a leap forward in comparison with other generative AI services for images — it's a Napster-to-Apple inflection point that bodes well for the future of creativity.",
#    'url': 'https://www.forrester.com/blogs/generative-ai-gets-an-upgrade-to-business-class-with-adobe-firefly/',
#    'urlToImage': 'https://go.forrester.com/wp-content/uploads/2023/03/Adobe-Firefly-21-Mar-2023.png',
#    'publishedAt': '2023-03-21T10:15:11Z',
#    'content': 'You might have had a feeling of déjà vu today when Adobe announced its Firefly generative AI service that lets you produce sets of new images by typing a description of what you have in mind, since t… [+5988 chars]'},
#   {'source': {'id': None, 'name': 'Forrester.com'},
#    'author': 'David Truog',
#    'title': 'Generative AI Gets An Upgrade To Business Class With Adobe Firefly',
#    'description': 'Adobe’s new Firefly service is a leap forward in comparison with other generative AI services for images — it’s a Napster-to-Apple inflection point that bodes well for the future of creativity.',
#    'url': 'https://www.forrester.com/blogs/generative-ai-adobe-firefly/',
#    'urlToImage': 'https://go.forrester.com/wp-content/uploads/2023/03/Adobe-Firefly-21-Mar-2023.png',
#    'publishedAt': '2023-03-21T10:15:11Z',
#    'content': 'You might have had a feeling of déjà vu today when Adobe announced its Firefly generative AI service that lets you produce sets of new images by typing a description of what you have in mind, since t… [+6015 chars]'},
#   {'source': {'id': None, 'name': 'TheGrio'},
#    'author': 'Associated Press',
#    'title': 'Anti-government protests in Kenya lead to opposition arrests',
#    'description': 'NAIROBI, Kenya (AP) — At least three Kenyan legislators and several protesters have been arrested and then released for participating\nThe post Anti-government protests in Kenya lead to opposition arrests appeared first on TheGrio.',
#    'url': 'http://thegrio.com/2023/03/21/anti-government-protests-in-kenya-lead-to-opposition-arrests/',
#    'urlToImage': 'https://thegrio.com/wp-content/uploads/2023/03/AP23079351188091-scaled.jpg',
#    'publishedAt': '2023-03-21T10:15:00Z',
#    'content': 'Protesters took to the streets of the Kenyan capital over the result of the last election and the rising cost of living.\r\nNAIROBI, Kenya (AP) At least three Kenyan legislators and several protesters … [+3138 chars]'}]}

# %%
#article_content = response['articles'][0]['content']
#article_content

#all_contents = ''

#for article in response['articles']:
    #content = article['content']
    #all_contents += content

    

for article in response['articles']:
    content = article['content']
    if content:
        try:
            if langdetect.detect(content) == 'en':
                print(content)
        except:
            pass
# Out:
# AUSTIN, TEXAS - MARCH 15: Henk Rogers attends the "Tetris" world premiere at SXSW at The Paramount ... [+] Theatre on March 15, 2023 in Austin, Texas. (Photo by Rick Kern/FilmMagic)
# FilmMagic
# The r… [+5621 chars]
# MACRO, the multi-platform media company, founded by Charles D. King, today announced the completion of an over $90 million minority investment led by BlackRock Alternatives, through the BlackRock Imp… [+10054 chars]
# In 2022, the global smartphone market faced macroeconomic difficulties that led to a 12% YoY decline in overall sales. However, there was a contrasting growth in the global premium smartphone market,… [+4016 chars]
# The NFL began the Hard Knocks series all the way back in 2001 with the defending Super Bowl champion Baltimore Ravens. Over the years, 17 different NFL teams have been featured on the series, with th… [+2295 chars]
# I have taken many inquiries on Site Reliability Engineering (SRE) in the last couple of years.  I&amp;O leaders are under high pressure to deliver reliable services at an unprecedented pace.They want… [+1025 chars]
# Blend Images - JGI/Jamie Grill
# Maintaining a personal checking account is practically a necessity in this day and age. Unfortunately, many banks make opening new accounts a hassle.
# Find Out: Heres … [+4960 chars]
# $95 . . .
#  Apple . : « , Apple. Apple , , . , , , ».
#  $95 ? . , , , , $500 .
#   Telegram. !
#  ?  -.
# Do the fans of the Boston Celtics expect too much from the team? On one hand, they want the ball club to win every game they can in the 2022-23 regular season. But on the other, they also want the te… [+869 chars]
# This is probably what the "taptic buttons" of the Apple iPhone 15 Pro will look like
# It will be another six months before we get the Apple iPhone 15 series announced by Tim Cook. Nevertheless, tipst… [+1967 chars]
# We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]
# Chicken Gyros feature the most incredible marinated chicken breast meat, fresh veggies, and homemade tzatziki sauce all wrapped up in a pita! These easy to make handheld entrees are Greek in origin a… [+8093 chars]
# This is the full transcript for season 4, episode 7 of the Quartz Obsession podcast on the invisible hand.
# Listen on: Apple Podcasts | Spotify | Google | Stitcher
# Nalis: There are concepts out ther… [+16896 chars]
# What drives the global economy? Any student of economics is likely to mention the invisible handthe collective self-interest that acts as the markets guiding force in a more powerful and beneficial w… [+1520 chars]
# Jeff Speck [00:00:00] That's absolutely one of my favorites. Many of my favorite books are the ones that were the most work. It is wonderful, wonderful.
# Anne Bogel [00:00:07] A lot of work, but the … [+53554 chars]
# The Worldcoin orb resembles a bowling ball conceived by Steve Jobs or an oversized Magic 8 ball possessed by HAL 9000. Its glossy exterior envelops the sphere, save for a gaping black circle in the f… [+12654 chars]
# Only a select few enterprises reach the exclusive $1 trillion market cap club. Those that do typically have their profit growth propelled by enduring global megatrends that enable them to deliver exc… [+4626 chars]
# THE recent online Spring gathering and forum of Community Growers held on Saturday, March 11, saw attendees, including Dónal McCormack of Blessington Allotments, unanimously backing calls for revised… [+2078 chars]
# , Apple LG Display OLED-, Samsung Display iPhone 14 Pro Max. Samsung OLED- Apple, , iPhone 12 Pro iPhone 12 Pro Max. BOE LG Display. , Samsung Display OLED- Apple.
#  , Apple Watch Ultra Apple MicroLE… [+5 chars]
# We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]
# The iPhone mini line only lasted two generations. There was an iPhone 12 mini followed by an iPhone 13 mini, but then Apple went in the opposite direction and launched a larger iPhone 14 Plus, instea… [+2584 chars]
# Amazon is now offering one of the first chances to save on Apples newest 12.9-inch M2 iPad Pro. Discounting the Wi-Fi 512GB capacity to a new all-time low, you can now drop this flagship device to $1… [+2178 chars]
# iPhone 14 Pro Max 6.72796*1290460PPIApp1000HDR16002000 ProMotion Super Retina XDR 1 Hz120 HzAlways-On
# iPhone 14 ProA164nm160 6 CPU A1520%A16 Bionic 5 GPU 50% 16 17 iPhone 14 Pro Max 29iPhone 14
# iPh… [+51 chars]
# We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]
# The DUNE mouse by Fabio Verdelli Design Studio is one of the most striking examples of sculptural computer peripheries. Since much of the focus when designing tools like this falls on increasing func… [+615 chars]
# Black women make just 64 cents for every $1 paid to white men.
# NEW YORK (AP) U.S. employers are increasingly posting salary ranges for job openings, even in states where its not required by law, acc… [+7129 chars]
# 5 PR- AGIMA.     ,   50 .    2022- 1  ,   1,5 . AGIMA     .
#     - .   AGIMA,          10    .      , PR -   PR-.
# « PR   »
#    ,    ,    PR. , ,  .  , PR   .
# , :
#  , : SMS MMS-, , , e-mail-!
#     … [+2844 chars]
# Rick Ross has responded to his neighbors following their beef over a herd of buffalos that broke out of his land and into theirs.
# After they escaped, they were returned to the rapper.
# “To everybody… [+794 chars]
# When it comes to brand loyalty, especially in North America, Apple has the most loyal fan base of all. While the general public may prefer Android, the number one brand in smartphones is Apple hands … [+2534 chars]
# UNIX OS Raspbian
# (The Register )Southern California Linux Expo (SCALE) OS Apple Apple 5 Apple 1 2 Apple Linux Raspbian 2009 Linux
# (Bloomberg) -- Google has suspended PDD Holdings Inc.s main Chinese shopping app Pinduoduo after discovering malware in unsanctioned versions of the software, dealing a blow to one of the countrys bi… [+4476 chars]
# (Bloomberg) -- Apple Inc. is seeking changes in Indias labor laws as part of its effort to expand local production, and regional governments are yielding to its request as they are eager to snatch iP… [+2567 chars]
# It seems that the iPhone 15 will finally ditch the dreadful Lightning port and enter the modern USB-C age. Apple will have to comply with the EU's legislation and equip its phones with the standard p… [+1317 chars]
# Skip to contentType your search and hit enter
# When you purchase through links in our articles, we may earn a small commission. This doesn't affect our editorial independence
# .
# We are almost a whol… [+4042 chars]
# We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]
# ForgeRock has become the first Identity management platform to make the leap into the brave new world of passwordless security.
# With what the company calls its Enterprise Connect Passwordless, users… [+2073 chars]
# Compatible
#  () MacBook: MacBook Pro (since 2016); MacBook (since 2015), MacBook Air (since 2018), etc. Apple: iPad Pro (2020/2018); iMac (since mid 2017); iMac Pro; Mac Mini (since 2018) etc() Micr… [+806 chars]
# Specifications:
#  Capacity: 12000 mAhInput: 8 pin 5V/2AOutput:
#  USB 1: 5V/3AUSB 2: 5 V/3 A
#  Dimensions: 14.2 cm x 7.36 cm x 1.5 cm. Weight: 330 g
#  Box contents:
#  1 x Pilot 4GS power bank, 1 … [+476 chars]
# ChatGPT logo and rising stock graph are seen in this illustration - REUTERS/Dado Ruvic/Illustration/File Photo
# In February I asked ChatGPT to invest for me and make a portfolio to grow my savings.
# … [+4078 chars]
# Apple Studios Hello Sunshine Maybe Next Time Deadline. , Apple Original Film.
#  , , . - : . , , , . , , . . Maybe Next Time 7 .
#  Hello Sunshine Apple Studios «, » (The Last Thing He Told Me), Apple … [+33 chars]
# If you're often misplacing your keys, bag, wallet or other valuable item, an AirTag tracker is a worthwhile investment. The diminutive item trackers can easily be dropped into a bag pocket or attache… [+1553 chars]
# With help from Eli Okun and Garrett Ross
# While we dont know for sure what crime that Manhattan DA Alvin Bragg will allege, the weight of available evidence suggests Donald Trump will be charged with… [+24112 chars]
# Terms &amp; Conditions
# New to Menulog customers: Get $15 off your first order when you use Apple Pay in the Menulog iOS app. Minimum spend of $30 required, excluding Service Fees. Delivery fee appli… [+1456 chars]
# Comedian David Mitchell once offered this truth on the British game show Would I Lie To You?:
# One of the codes I live my life by is that my appearance should be in no way noteworthy. But then again,… [+6909 chars]
# Lilles Series Mania Forum is kicking off today with a packed schedule of talks, screenings and competitions.Fighting it out in International Competition are the likes of Prime Videos Toni Collette st… [+312 chars]
# The Kremlin has decided iPhones are no longer safe to use by anyone who works within the Russian government.
# According to Russian newspaper Kommersant, Sergei Kiriyenko, Russia's first deputy chief … [+1584 chars]
# The Kremlin has decided iPhones are no longer safe to use by anyone who works within the Russian government.
# According to Russian newspaper Kommersant, Sergei Kiriyenko, Russia's first deputy chief … [+1584 chars]
# -  third-party cookies. «»- ,   , .   Stable ID. AdTech- Quiet Media  -   AdRiver   Stable ID.   , Sostav .
# third-party cookies   . - ,   , . , ,   , cookies.   ID,     — .
#   , «», : IDFA —     iOS… [+1447 chars]
# A GB boxer dubbed a "future world champion" has died suddenly, aged 19.
# The family of Jude Moore, from Bristol, confirmed the nexpected passing of the "uniquely talented fighter" who was tragically … [+1756 chars]
# You might have had a feeling of déjà vu today when Adobe announced its Firefly generative AI service that lets you produce sets of new images by typing a description of what you have in mind, since t… [+5988 chars]
# You might have had a feeling of déjà vu today when Adobe announced its Firefly generative AI service that lets you produce sets of new images by typing a description of what you have in mind, since t… [+6015 chars]
# Protesters took to the streets of the Kenyan capital over the result of the last election and the rising cost of living.
# NAIROBI, Kenya (AP) At least three Kenyan legislators and several protesters … [+3138 chars]

# %%
content
# Out:
# 'Protesters took to the streets of the Kenyan capital over the result of the last election and the rising cost of living.\r\nNAIROBI, Kenya (AP) At least three Kenyan legislators and several protesters … [+3138 chars]'

# %%
analyzer = SentimentIntensityAnalyzer()
sentiment_score = analyzer.polarity_scores(article_content)
sentiment_score

# %%
news_content_score = sentiment_score['compound']
