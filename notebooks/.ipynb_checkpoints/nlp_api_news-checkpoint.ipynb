# %% [markdown]
# # API News exploration

# %% [markdown]
# ## Exploring Polygon API for news to conduct eventually NLP, sentiment analysis

# %%
#lib imports
from api_key import news_key
import requests
import pandas as pd
import numpy as np

# %%
company = 'apple'
country = 'us'
#url = f'https://newsapi.org/v2/everything?q={company}&from=2023-03-16&country={country}&sortBy=publishedAt&apiKey={news_key}'
f'https://newsapi.org/v2/everything?q={country}&from=2023-03-10&to=2023-03-16&sortBy=popularity&apiKey={news_key}'
response = requests.get(url)
response = response.json()
response
# Out:
# {'status': 'ok',
#  'totalResults': 36,
#  'articles': [{'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Annette Choi, Han Vu',
#    'title': 'Ozempic shortage: Diabetes patients at risk as TikTok and telehealth prescriptions fuel drug demand - CNN',
#    'description': 'Telehealth and social media are playing a significant role in driving demand for Ozempic, a prescription drug that treats Type 2 diabetes, experts told CNN. The current drug shortage has limited access for patients with diabetes who rely on it to control thei…',
#    'url': 'https://www.cnn.com/2023/03/17/health/ozempic-shortage-tiktok-telehealth/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230316130100-20230316-ozempic-shortage-card.png?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-17T11:47:00Z',
#    'content': 'Telehealth and social media are playing a significant role in driving demand for Ozempic, a prescription drug that treats Type 2 diabetes, experts told CNN. The current drug shortage has limited acce… [+5984 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Guardian sport',
#    'title': 'Champions League: Chelsea draw Real Madrid, Manchester City land Bayern - The Guardian',
#    'description': 'Chelsea will play Real Madrid in the Champions League quarter-finals and Manchester City will face Bayern Munich',
#    'url': 'https://www.theguardian.com/football/2023/mar/17/champions-league-draw-chelsea-real-madrid-manchester-city-bayern-munich-quarter-finals',
#    'urlToImage': 'https://i.guim.co.uk/img/media/6634a88fd848758f8d4a9f9ee93174a99f8b47a5/0_547_8208_4925/master/8208.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=9ae324ad299a54a19e5a38f5ccbfe83c',
#    'publishedAt': '2023-03-17T11:45:00Z',
#    'content': 'Chelsea will play Real Madrid in the Champions League quarter-finals and Manchester City will face Bayern Munich after Fridays draw gave the Premier Leagues two remaining clubs among the hardest poss… [+2012 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Nectar Gan, Anna Chernova',
#    'title': "China's Xi to meet Putin in Russia next week - CNN",
#    'description': 'Chinese leader Xi Jinping will fly to Moscow next week to meet with President Vladimir Putin in his first visit to Russia since Putin launched his devastating invasion of Ukraine more than a year ago.',
#    'url': 'https://www.cnn.com/2023/03/17/china/china-xi-jinping-visits-russia-intl-hnk/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/230314071624-01-npc-xi-jinping-031223.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2023-03-17T11:40:00Z',
#    'content': 'Chinese leader Xi Jinping will fly to Moscow next week to meet with President Vladimir Putin in his first visit to Russia since Putin launched his devastating invasion of Ukraine more than a year ago… [+3923 chars]'},
#   {'source': {'id': 'the-washington-post', 'name': 'The Washington Post'},
#    'author': 'Niha Masih',
#    'title': 'France protests: Why is Macron forcing a retirement-age hike? - The Washington Post',
#    'description': 'The French government angered protesters after using Article 49.3, an executive power, to raise the retirement age without the consent of the National Assembly.',
#    'url': 'https://www.washingtonpost.com/world/2023/03/17/france-protests-retirement-age-macron/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://d1i4t8bqe7zgj6.cloudfront.net/03-17-2023/t_0894e7dc243f44e2bc59c25c6b4619e3_name_T5TO4HXOBRMQEFCCEDLFVASAPA_scaled.jpg&w=1440',
#    'publishedAt': '2023-03-17T11:24:00Z',
#    'content': 'Comment on this story\r\nLarge-scale protests erupted across several French citiesafter President Emmanuel Macrons government forced through a contentious pension bill without a key Parliament vote, es… [+4130 chars]'},
#   {'source': {'id': None, 'name': 'Bloody Elbow'},
#    'author': 'Tim Bissell',
#    'title': 'UFC 286: Edwards vs. Usman 3 weigh-in live stream - Bloody Elbow',
#    'description': 'See what happens on the scales ahead of UFC 286.',
#    'url': 'https://www.bloodyelbow.com/2023/3/16/23636192/ufc-286-weigh-ins',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/BcGCBvuzIDOrVeaeFuft3EytIHE=/0x0:6000x3141/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/24513101/1242600187.jpg',
#    'publishedAt': '2023-03-17T10:36:00Z',
#    'content': 'The UFC is in the UK this weekend with UFC welterweight champion Leon Edwards hoping to make a successful first title defence, while standing on home soil. His challenger will be the man he took the … [+2609 chars]'},
#   {'source': {'id': None, 'name': "Investor's Business Daily"},
#    'author': "Investor's Business Daily",
#    'title': "Futures: Market Rally Needs To Do This; FedEx Soars Past Buy Point - Investor's Business Daily",
#    'description': None,
#    'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-market-rally-needs-to-this-fedex-soars-past-buy-point/',
#    'urlToImage': None,
#    'publishedAt': '2023-03-17T10:30:18Z',
#    'content': None},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Slovakia sends MIG-29 fighter jets to Ukraine - PM - Reuters',
#    'description': "Slovakia on Friday became the second of Ukraine's allies to provide MIG-29 fighter jets which Kyiv believes are crucial to repel Russia's year-long invasion.",
#    'url': 'https://www.reuters.com/world/europe/slovak-government-send-mig-29-fighter-jets-ukraine-pm-2023-03-17/',
#    'urlToImage': 'https://www.reuters.com/resizer/eIlugTA9oxwmnJu514m6xJ5m-Fw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2GZP5JBGPVPHVNHWPZHO52RJTQ.jpg',
#    'publishedAt': '2023-03-17T10:30:00Z',
#    'content': "March 17 (Reuters) - Slovakia on Friday became the second of Ukraine's allies to provide MIG-29 fighter jets which Kyiv believes are crucial to repel Russia's year-long invasion.\r\nSlovakia joined Pol… [+1967 chars]"},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Michael Sainato',
#    'title': "Low-income Americans face a 'hunger cliff' as Snap benefits are cut - The Guardian",
#    'description': 'The US food assistance program offered expanded benefits during the Covid emergency, but they ended last month',
#    'url': 'https://www.theguardian.com/society/2023/mar/17/snap-food-benefits-us-cuts-impact-families',
#    'urlToImage': 'https://i.guim.co.uk/img/media/d915f1df50523de10c7e7c5bf9b26dbe37ce26b0/0_200_6000_3600/master/6000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=72349b40cd985c94da4114df3fb1ed5f',
#    'publishedAt': '2023-03-17T08:02:00Z',
#    'content': 'Gina Melton is facing a dilemma. Like millions of other Americans, Melton and her family relied on food assistance benefits boosted by Congress to help them through the pandemic. Now that extra cash … [+5660 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Jihye Lee, Lim Hui Jie',
#    'title': 'Asia markets rise as Wall Street banks move to shore up banking system - CNBC',
#    'description': 'Asian markets traded higher after banks on Wall Street pledged to deposit $30 billion in First Republic.',
#    'url': 'https://www.cnbc.com/2023/03/17/asia-markets-banks-europe-us-rescue-plans.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/107210376-1679009116726-gettyimages-1473992335-0j5a4522_pom8amiv.jpeg?v=1679011935&w=1920&h=1080',
#    'publishedAt': '2023-03-17T07:52:00Z',
#    'content': 'Asia-Pacific markets were higher Friday after major Wall Street banks pledged a deposit of $30 billion in First Republic Bank in an attempt to bolster confidence in the banking system. The group of 1… [+1457 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'John Bacon, Jorge L. Ortiz, Tom Vanden Brook',
#    'title': "Russia to try to salvage wrecked US drone; Gen. Milley says 'not a lot to recover': Ukraine war updates - USA TODAY",
#    'description': 'Two Russian SU-27 fighters conducted an intercept\xa0of the MQ-9\xa0drone Tuesday, forcing US operators to crash it in the Black Sea. Updates.',
#    'url': 'https://www.usatoday.com/story/news/world/2023/03/15/ukraine-russia-war-live-updates/11476301002/',
#    'urlToImage': 'https://www.gannett-cdn.com/presto/2023/03/15/USAT/410f5fe7-b1b1-43ff-8c81-388a8d8d7526-AP_Russia_Ukraine_War_32.jpg?crop=5560,3128,x0,y153&width=3200&height=1801&format=pjpg&auto=webp',
#    'publishedAt': '2023-03-17T07:50:00Z',
#    'content': 'Russia will attempt to retrieve and study the wreckage of the American MQ-9 drone that crashed into the Black Sea after being harassed by Russian fighter jets.\r\nNikolai Patrushev, secretary of the Ru… [+8197 chars]'},
#   {'source': {'id': None, 'name': 'YouTube'},
#    'author': None,
#    'title': 'Resident Evil 4 Remake Review - GameSpot',
#    'description': "Capcom raises the bar for what a good remake is and simultaneously preserves Resident Evil 4's legacy as a genre-defining experience and one of the greatest ...",
#    'url': 'https://www.youtube.com/watch?v=abxjlXTj_PI',
#    'urlToImage': 'https://i.ytimg.com/vi/abxjlXTj_PI/maxresdefault.jpg',
#    'publishedAt': '2023-03-17T07:01:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'AnandTech'},
#    'author': 'Ryan Smith',
#    'title': 'Qualcomm Announces Snapdragon 7+ Gen 2: Premium Segment SoC Gets a Cortex-X CPU Core - AnandTech',
#    'description': 'After a 2021/2022 product cycle that was a bit more interesting than Qualcomm perhaps would have liked, 2023 has been a far more straightforward...',
#    'url': 'https://www.anandtech.com/show/18775/qualcomm-announces-snapdragon-7-gen-2-premium-segment-gets-a-cortexx-core',
#    'urlToImage': 'https://images.anandtech.com/doci/18775/SD7PG2_Logo_678x452.jpg',
#    'publishedAt': '2023-03-17T07:00:00Z',
#    'content': 'After a 2021/2022 product cycle that was a bit more interesting than Qualcomm perhaps would have liked, 2023 has been a far more straightforward year for the prolific SoC and cellular modem vendor. A… [+9280 chars]'},
#   {'source': {'id': None, 'name': 'YouTube'},
#    'author': None,
#    'title': 'UCLA First Round Postgame Press Conference - 2023 NCAA Tournament - March Madness',
#    'description': 'Watch full press conferences from the men’s and women’s 2023 NCAA Tournament, as well as highlights, game recaps and much more from March Madness. Subscribe ...',
#    'url': 'https://www.youtube.com/watch?v=D0ppZ_9sfTc',
#    'urlToImage': 'https://i.ytimg.com/vi/D0ppZ_9sfTc/maxresdefault.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGFYgWChlMA8=&rs=AOn4CLBKjy7rbYiOKPKQDu-gVaSt3ACPUw',
#    'publishedAt': '2023-03-17T04:44:45Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'YouTube'},
#    'author': None,
#    'title': 'Xcel Energy cleaning up radioactive leak in Monticello - WCCO - CBS Minnesota',
#    'description': 'According to state officials, 400,000 gallons of water contaminated with tritium leaked from a water pipe running between two buildings at the facility.',
#    'url': 'https://www.youtube.com/watch?v=r5c6j7UZZA0',
#    'urlToImage': 'https://i.ytimg.com/vi/r5c6j7UZZA0/maxresdefault.jpg',
#    'publishedAt': '2023-03-17T04:17:06Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'NBC 5 Dallas-Fort Worth'},
#    'author': None,
#    'title': "14-Year-Old Nicknamed ‘El Chapito' Arrested in Mexico for Murder of 8 at a Birthday Party - NBC 5 Dallas-Fort Worth",
#    'description': 'The boy allegedly rode up on a motorcycle and opened fire on a family in the low-income Mexico City suburb of Chimalhuacan.',
#    'url': 'https://www.nbcdfw.com/news/national-international/14-year-old-nicknamed-el-chapito-arrested-in-mexico-for-murder-of-8/3216680/',
#    'urlToImage': 'https://media.nbcdfw.com/2023/03/GettyImages-968584294.jpg?quality=85&strip=all&resize=1200%2C675',
#    'publishedAt': '2023-03-17T03:54:40Z',
#    'content': 'Mexican authorities have arrested a 14-year-old boy nicknamed El Chapito for the drug-related killing of eight people near Mexico City, the federal Public Safety Department said Thursday.\r\nThe boy al… [+1364 chars]'},
#   {'source': {'id': 'al-jazeera-english', 'name': 'Al Jazeera English'},
#    'author': 'Al Jazeera',
#    'title': 'Japan, South Korea move to mend ties at landmark summit - Al Jazeera English',
#    'description': 'Leaders Yoon and Kishida find common ground on contentious issues amid growing regional security challenges.',
#    'url': 'https://www.aljazeera.com/news/2023/3/17/japan-south-korea-move-to-mend-ties-at-landmark-summit',
#    'urlToImage': 'https://www.aljazeera.com/wp-content/uploads/2023/03/2023-03-16T150217Z_1359672167_RC22VZ9MF0YF_RTRMADP_3_JAPAN-SOUTHKOREA.jpg?resize=1920%2C1440',
#    'publishedAt': '2023-03-17T03:45:59Z',
#    'content': 'The leaders of Japan and South Korea were all smiles as they agreed to put a century of difficult history to one side and work together to counter regional security challenges.\r\nThe Tokyo summit betw… [+4733 chars]'},
#   {'source': {'id': None, 'name': 'Hollywood Reporter'},
#    'author': 'Carly Thomas',
#    'title': 'Drew Barrymore Shares Wholesome Response to Hugh Grant Calling Her Singing “Horrendous” in ‘Music and Lyrics’ - Hollywood Reporter',
#    'description': 'During a recent interview, the \'Love Actually\' star joked about her singing in the 2007 rom-com, saying, "I\'ve heard dogs bark better than she sings."',
#    'url': 'https://www.hollywoodreporter.com/movies/movie-news/drew-barrymore-responds-hugh-grant-calling-singing-horrendous-music-and-lyrics-1235354929/',
#    'urlToImage': 'https://www.hollywoodreporter.com/wp-content/uploads/2023/03/Drew-Barrymore-and-Hugh-Grant-Music-and-Lyrics-everett-H-2023.jpg?w=1024',
#    'publishedAt': '2023-03-17T03:39:44Z',
#    'content': 'Drew Barrymore is proving to Hugh Grant just what her voice can do after he jokingly called her singing “horrendous.”\r\nDuring a WIRED video interview posted Monday, where he answers “the web’s most-s… [+1549 chars]'},
#   {'source': {'id': None, 'name': 'YouTube'},
#    'author': None,
#    'title': "Arizona players react to first-round loss to Princeton | 2023 NCAA Men's Basketball Tournament - Pac-12 Networks",
#    'description': "Pac-12 Networks' Ashley Adamson spoke to Arizona student-athletes Oumar Ballo, Pelle Larsson, Kerr Kriisa and Courtney Ramey after the Wildcats lost to Princ...",
#    'url': 'https://www.youtube.com/watch?v=ErpCz1uVx50',
#    'urlToImage': 'https://i.ytimg.com/vi/ErpCz1uVx50/hqdefault.jpg',
#    'publishedAt': '2023-03-17T02:53:02Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'YouTube'},
#    'author': None,
#    'title': 'Race for AI dominance: Microsoft announces new Chatbot - CoPilot | World News | Tech News | WION - WION',
#    'description': 'Microsoft is planning to put Artificial Intelligence into the hands of more users. It has announced a new Chatbot - CoPilot - that will apply ChatGPT like ab...',
#    'url': 'https://www.youtube.com/watch?v=gwm9xAt9lr8',
#    'urlToImage': 'https://i.ytimg.com/vi/gwm9xAt9lr8/maxresdefault.jpg',
#    'publishedAt': '2023-03-17T02:50:45Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'New York Post'},
#    'author': 'Johnny Oleksinski',
#    'title': "'Parade' Broadway review: Flawed musical gets heartfelt revival - New York Post ",
#    'description': 'The play’s greatest asset is youth.',
#    'url': 'https://nypost.com/2023/03/16/parade-broadway-review-flawed-musical-gets-heartfelt-revival/',
#    'urlToImage': 'https://nypost.com/wp-content/uploads/sites/2/2023/03/NYPICHPDPICT000008306150.jpg?quality=75&strip=all&w=1024',
#    'publishedAt': '2023-03-17T02:01:33Z',
#    'content': 'The greatest asset of the Broadway revival of Parade,” Jason Robert Browns sorrowful if flawed musical about the 1915 anti-Semitic lynching of Leo Frank, is youth.\r\nPlaying husband and wife Leo and L… [+4767 chars]'}]}

# %%
article_description = response['articles'][0]['description']
article_description

# %%
article_description_list = []
articles = article_description

for article in article_description_list:
    description = article['description']
    print(description)
