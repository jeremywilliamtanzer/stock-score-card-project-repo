# %% [markdown]
# # API News exploration

# %% [markdown]
# ## Exploring Polygon API for news to conduct eventually NLP, sentiment analysis

# %%
#lib imports
from api_key import news_key
import requests
import pandas as pd
import numpy as np
import api_test_alone
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 6
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 from back_end import api_test_alone
#
# ModuleNotFoundError: No module named 'back_end'

# %%
url = f'https://newsapi.org/v2/everything?q=tesla&from=2023-02-16&sortBy=publishedAt&apiKey={news_key}'
response = requests.get(url)
response = response.json()
response
# Out:
# {'status': 'ok',
#  'totalResults': 12848,
#  'articles': [{'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Daniel Foelber and Howard Smith)',
#    'title': 'Near 52-Week Lows, 2 EV Stocks Worth Considering Now',
#    'description': 'Rivian and Nio could be worth a look even if both stocks continue to fall.',
#    'url': 'https://www.fool.com/investing/2023/03/15/near-52-week-lows-ev-stock-buy-worth-considering/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/724021/2022-rivian-r1t-01.jpeg',
#    'publishedAt': '2023-03-15T12:45:00Z',
#    'content': "On March 13, Rivian Automotive(RIVN -3.79%) reached a new all-time intraday low of $13.13 per share. The stock's fall from grace from one of the most valuable automakers in the world to being worth a… [+5602 chars]"},
#   {'source': {'id': None, 'name': 'Automotive News'},
#    'author': 'Kristen Strakalaitis, Jack Hallauer',
# ...

# %%
article_url = response['articles'][0]['description']
article_url
# Out:
# 'Rivian and Nio could be worth a look even if both stocks continue to fall.'

# %%
article = requests.get(article_url)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 article.text()
#
# TypeError: 'str' object is not callable
