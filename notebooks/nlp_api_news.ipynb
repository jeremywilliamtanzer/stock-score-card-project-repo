# %% [markdown]
# # API News exploration

# %% [markdown]
# ## Exploring Polygon API for news to conduct eventually NLP, sentiment analysis

# %%
#lib imports
from api_key import news_key
import requests
import pandas as pd
import numpy as np

# %%
url = f'https://newsapi.org/v2/everything?q=apple&from=2023-02-16&sortBy=publishedAt&apiKey={news_key}'
response = requests.get(url)
response = response.json()
response
# Out:
# {'status': 'ok',
#  'totalResults': 45930,
#  'articles': [{'source': {'id': 'cbs-news', 'name': 'CBS News'},
#    'author': 'Danica Creahan',
#    'title': 'NCAA March Madness 2023: How to watch the Nevada vs. Arizona State game tonight',
#    'description': "Here's what you need to know about how to watch the 2023 NCAA Tournament, including the First Four games.",
#    'url': 'https://www.cbsnews.com/essentials/ncaa-march-madness-2023-how-to-watch-the-nevada-vs-arizona-state-game-tonight/',
#    'urlToImage': 'https://assets2.cbsnewsstatic.com/hub/i/r/2023/03/14/66c41bdd-0b13-4034-a868-74c1e67a8279/thumbnail/1200x630/592c7787d305731c4f5aa371c84b9860/gettyimages-1473409357.jpg',
#    'publishedAt': '2023-03-15T13:14:15Z',
#    'content': "Ethan Miller/Getty Images\r\nMarch Madness season is here. With 68 teams playing in 67 live games across the country, from Dayton, Ohio to New York City, there's a lot of action to follow over the next… [+10678 chars]"},
# ...

# %%
article_description = response['articles'][0]['description']
article_description
# Out:
# "Here's what you need to know about how to watch the 2023 NCAA Tournament, including the First Four games."

# %%
article_description_list = []
articles = article_description

for article in article_description_list:
    description = article['description']
    print(description)
