# %% [markdown]
# # API News exploration

# %% [markdown]
# ## Exploring Polygon API for news to conduct eventually NLP, sentiment analysis

# %%
#lib imports
import os
import langdetect
import requests
import pandas as pd
import numpy as np
import nltk
from gensim.models import Word2Vec
from datetime import date
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
NEWS_KEY = os.environ.get('NEWS_KEY')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jtanzer/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
today = date.today()
today = today.strftime("%d-%m-%Y")

# %%
today
# Out:
# '22-03-2023'

# %%
company_name = 'apple'
country = 'us'
url = f'https://newsapi.org/v2/everything?q={company_name}&from={today}&sortBy=publishedAt&apiKey={NEWS_KEY}'
#url = f'https://newsapi.org/v2/everything?q={country}&from=2023-03-17&to=2023-03-18&sortBy=popularity&apiKey={NEWS_KEY}'
response = requests.get(url)
response = response.json()
response
# Out:
# {'status': 'ok',
#  'totalResults': 46575,
#  'articles': [{'source': {'id': None, 'name': 'Hplusmagazine.com'},
#    'author': 'abhishek',
#    'title': 'Search End Result For Bet365',
#    'description': 'Search End Result For Bet365 Reply Amazing submit it is stuffed with information and informative content good work stick with it. Are you having points converting the worth of bits into real money, like the US dollar? Then, don’t fret...',
#    'url': 'https://hplusmagazine.com/2023/03/21/search-end-result-for-bet365-21/',
#    'urlToImage': 'https://hplusmagazine.com/wp-content/uploads/2020/06/cropped-transhumanism_h_2-svg-1.png',
#    'publishedAt': '2023-03-21T11:48:14Z',
#    'content': 'Reply Amazing submit it is stuffed with information and informative content good work stick with it. Are you having points converting the worth of bits into real money, like the US dollar? Then, don’… [+31387 chars]'},
#   {'source': {'id': None, 'name': 'Imagazine.pl'},
#    'author': 'Krzysztof Kołacz',
#    'title': 'iPhone 15 – kolejne rendery i doniesienia',
#    'description': 'W sieci pojawiły się kolejne wizualizacje przedstawiające nadchodzącego iPhone’a 15 Pro. Są też nowe informacje w sprawie USB-C. „Made for iPhone” niemal pewne dla USB-C Analityk Ming-Chi Kuo poinformował w poniedziałek, że port USB-C, który zastosuje Apple t…',
#    'url': 'https://imagazine.pl/2023/03/21/iphone-15-kolejne-rendery-i-doniesienia/',
#    'urlToImage': 'https://imagazine.pl/wp-content/uploads/2023/03/screen-post-LK0CQgHYAT8-unsplash.jpg',
#    'publishedAt': '2023-03-21T11:48:01Z',
#    'content': 'W\xa0sieci pojawiy si kolejne wizualizacje przedstawiajce nadchodzcego iPhone’a 15 Pro. S\xa0te nowe informacje w\xa0sprawie USB-C.\r\nMade for iPhone niemal pewne dla USB-C\r\nAnalityk Ming-Chi Kuo poinformowa w… [+1907 chars]'},
#   {'source': {'id': None, 'name': 'WSMV Nashville'},
#    'author': 'The Associated Press',
#    'title': '‘Ted Lasso’ visits White House, promotes mental health care',
#    'description': 'Fictional soccer coach Ted Lasso used a White House visit Monday to encourage people, even in politically divided Washington, to make it a point to check in often with friends, family and co-workers to “ask how they’re doing, and listen, sincerely.”',
#    'url': 'https://www.wsmv.com/2023/03/20/ted-lasso-visits-white-house-promotes-mental-health-care/',
#    'urlToImage': 'https://gray-wsmv-prod.cdn.arcpublishing.com/resizer/1nwUx2CwpJkhbZPGx6ai7pRutKk=/1200x600/smart/filters:quality(85)/cloudfront-us-east-1.images.arcpublishing.com/gray/TRLAAVRNHRCYXFWS7JPFEQSMLE.jpg',
#    'publishedAt': '2023-03-21T11:47:57Z',
#    'content': 'WASHINGTON (AP) Fictional soccer coach Ted Lasso used a White House visit Monday to encourage people, even in politically divided Washington, to make it a point to check in often with friends, family… [+3909 chars]'},
#   {'source': {'id': None, 'name': 'Giga'},
#    'author': 'Martin Hartmann',
#    'title': 'Xbox-Chef offenbart seinen Masterplan: „Ich denke, das ist eine riesige Chance“',
#    'description': 'Um auch in Zukunft mit PlayStation und Nintendo Switch mithalten zu können, will Xbox-Chef Phil Spencer die eigene Konsole breit aufstellen. Dafür enthüllt er jetzt seinen Masterplan, der besonders Gamern am Smartphone zugutekommt.',
#    'url': 'https://www.giga.de/news/xbox-chef-offenbart-seinen-masterplan-ich-denke-das-ist-eine-riesige-chance/',
#    'urlToImage': 'https://crops.giga.de/74/50/2c/d5def891c9956fded3d889d655_YyAxODA1eDk0Mys1OCs2OAJyZSAxMjAwIDYyNwM3MGRlOTk2ZWQ5NQ==.jpg',
#    'publishedAt': '2023-03-21T11:46:27Z',
#    'content': 'Um auch in Zukunft mit PlayStation und Nintendo Switch mithalten zu können, will Xbox-Chef Phil Spencer die eigene Konsole breit aufstellen. Dafür enthüllt er jetzt seinen Masterplan, der besonders G… [+1732 chars]'},
#   {'source': {'id': None, 'name': 'Bolsamania.com'},
#    'author': 'César Nuez',
#    'title': 'Compañías que se deben tener muy en cuenta por técnico este martes en Wall Street',
#    'description': 'Apple se encuentra atacando ya la resistencia de los 157,38 dólares.',
#    'url': 'https://www.bolsamania.com/noticias/analisis-tecnico/companias-que-se-deben-tener-muy-en-cuenta-por-tecnico-este-martes-en-wall-street--12741674.html',
#    'urlToImage': 'https://img4.s3wfg.com/web/img/images_uploaded/5/8/cbwallstreetsombra.jpg',
#    'publishedAt': '2023-03-21T11:46:02Z',
#    'content': 'Apple se encuentra atacando ya la resistencia de los 157,38 dólares.\r\nEn cuanto confirme la superación de este nivel de precios podríamos ver una extensión de las subidas hasta el nivel de los 176,15… [+575 chars]'},
#   {'source': {'id': None, 'name': '01net.com'},
#    'author': 'Florian Bayard',
#    'title': 'Amazon décrète de nouveaux licenciements, et Twitch n’y échappe pas',
#    'description': 'Amazon continue de réduire ses effectifs. Après la croissance monstre des années Covid, le géant du commerce en ligne doit se serrer la ceinture. Twitch, la plate-forme de streaming du groupe, est fortement affectée par les réductions budgétaires décrétées…',
#    'url': 'https://www.01net.com/actualites/amazon-decrete-nouveaux-licenciements-twitch-echappe-pas.html',
#    'urlToImage': 'https://www.01net.com/app/uploads/2022/07/logo-amazon.jpg',
#    'publishedAt': '2023-03-21T11:45:14Z',
#    'content': 'Amazon continue de réduire ses effectifs. Après la croissance monstre des années Covid, le géant du commerce en ligne doit se serrer la ceinture. Twitch, la plate-forme de streaming du groupe, est fo… [+3512 chars]'},
#   {'source': {'id': None, 'name': 'Golem.de'},
#    'author': 'Simon Krebs',
#    'title': 'Anzeige: Apple iPad Pro mit 530 Euro Rabatt bei Amazon',
#    'description': 'Einige Produkte von Apple sind bei Amazon derzeit im Angebot. Neben verschiedenen Macbooks ist ein iPad Pro besonders deutlich reduziert. (iPad Pro, Notebook)',
#    'url': 'https://www.golem.de/sonstiges/zustimmung/auswahl.html?from=https%3A%2F%2Fwww.golem.de%2Fnews%2Fanzeige-apple-ipad-pro-mit-530-euro-rabatt-bei-amazon-2303-172799.html&referer=https%3A%2F%2Ft.co%2F77e96f99a1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:45:02Z',
#    'content': 'Besuchen Sie Golem.de wie gewohnt mit Werbung und Tracking,\r\n indem Sie der Nutzung aller Cookies zustimmen.\r\n Details zum Tracking finden Sie im Privacy Center.\r\nSkript wurde nicht geladen. Informat… [+607 chars]'},
#   {'source': {'id': None, 'name': 'Elchapuzasinformatico.com'},
#    'author': 'Protector Indefinido',
#    'title': 'Rusia: «O tiran los iPhone o se los dan a los niños, a partir del día 1 están prohibidos»',
#    'description': 'Putin no se fía de occidente, Rusia no va a tener ningún pudor en implementar medidas de seguridad muy amplias y la pregunta es, ¿por qué ahora? Tras más de un año de guerra, tras décadas de hostilidades y con China de la mano, no se hace muy entendible que s…',
#    'url': 'https://elchapuzasinformatico.com/2023/03/rusia-prohibicion-iphone-elecciones/',
#    'urlToImage': 'https://elchapuzasinformatico.com/wp-content/uploads/2023/03/Rusias-prohibicion-iPhone.jpg',
#    'publishedAt': '2023-03-21T11:44:51Z',
#    'content': 'Putin no se fía de occidente, Rusia no va a tener ningún pudor en implementar medidas de seguridad muy amplias y la pregunta es, ¿por qué ahora? Tras más de un año de guerra, tras décadas de hostilid… [+3019 chars]'},
#   {'source': {'id': 'techradar', 'name': 'TechRadar'},
#    'author': 'hamish.hector@futurenet.com (Hamish Hector)',
#    'title': 'Microsoft’s mobile Xbox Store could mean cheaper games on your iPhone',
#    'description': "Microsoft's planned mobile Xbox Game Store could see some apps and games get cheaper as it wouldn't split its revenue.",
#    'url': 'https://www.techradar.com/news/microsofts-mobile-xbox-store-could-mean-cheaper-games-on-your-iphone',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/VRVThXGaPBb8gYYRi4697h-1200-80.jpg',
#    'publishedAt': '2023-03-21T11:44:14Z',
#    'content': 'Microsoft-owned Xbox could be bringing its own app store to your Android and Apple phone according to the company’s gaming chief, Phil Spencer. If it does, we could see some of our favorite apps and … [+3532 chars]'},
#   {'source': {'id': None, 'name': 'Basicthinking.de'},
#    'author': 'Tour a Turquia',
#    'title': 'Kommentar zu Steve Jobs biologischer Vater erzählt die ganze Geschichte: Sagt hallo zu Abdulfattah John Jandali von Tour a Turquia',
#    'description': 'Ja sapperlot. Gerade wollte ich mich schon mit der Begründung in meine Phantasie flüchten, es passiere in der Technikszene nichts Überraschendes mehr, da tritt dieser Mann auf den Plan: Abdulfattah John Jandali, angeblich der biologische Vater des jüngst zurü…',
#    'url': 'https://www.basicthinking.de/blog/2011/08/29/steve-jobs-biologischer-vater-erzahlt-die-ganze-geschichte-sagt-hallo-zu-abdulfattah-john-jandali/',
#    'urlToImage': 'https://www.basicthinking.de/blog/wp-content/uploads/AbdulfattahJohnJendali.jpg',
#    'publishedAt': '2023-03-21T11:44:01Z',
#    'content': 'Ja sapperlot. Gerade wollte ich mich schon mit der Begründung in meine Phantasie flüchten, es passiere in der Technikszene nichts Überraschendes mehr, da tritt dieser Mann auf den Plan: Abdulfattah J… [+2927 chars]'},
#   {'source': {'id': None, 'name': 'Nfcw.com'},
#    'author': 'Tom Phillips',
#    'title': 'Apple Pay goes live in South Korea',
#    'description': 'Apple Pay has launched in South Korea with support for Mastercard, Visa and local debit and credit cards issued by Hyundai Card. Apple has added the country to its list of territories where the service is available and confirms on a support page in Korean tha…',
#    'url': 'https://www.nfcw.com/2023/03/21/382716/apple-pay-goes-live-in-south-korea/',
#    'urlToImage': 'https://www.nfcw.com/wp-content/uploads/2023/03/apple-pay-hyundai-card-korea.jpg',
#    'publishedAt': '2023-03-21T11:43:58Z',
#    'content': 'APPLE PAY: South Koreans can now add their credit or debit card to the Wallet app on their iPhone\r\nApple Pay has launched in South Korea with support for Mastercard, Visa and local debit and credit c… [+1492 chars]'},
#   {'source': {'id': None, 'name': 'Numerama'},
#    'author': 'Wilfried Apithy',
#    'title': 'L’iPhone 15 n’aura plus de boutons mécaniques, une petite révolution pour Apple',
#    'description': "Apple devrait retirer l'interrupteur et les boutons de volume sur les futurs iPhone 15 Pro et iPhone 15 Pro Max. Un véritable bouleversement, qui pourrait entraîner un chamboulement pour l’industrie ? Comme c'est le cas depuis plus de 16 ans, Apple devrait or…",
#    'url': 'https://www.numerama.com/tech/1311840-liphone-15-naura-plus-de-boutons-mecaniques-une-petite-revolution-pour-apple.html',
#    'urlToImage': 'https://www.numerama.com/wp-content/uploads/2023/03/bouton-iphone-15.jpg',
#    'publishedAt': '2023-03-21T11:41:54Z',
#    'content': 'Apple devrait retirer linterrupteur et les boutons de volume sur les futurs iPhone 15 Pro et iPhone 15 Pro Max. Un véritable bouleversement, qui pourrait entraîner un chamboulement pour lindustrie ?\r… [+3312 chars]'},
#   {'source': {'id': None, 'name': 'Olhardigital.com.br'},
#    'author': 'Wagner Edwards',
#    'title': '5 motivos para você investir em um smartwatch e melhorar sua saúde',
#    'description': 'O eletrônico detêm sensores que verificam a saúde do usuário e fornecem informações interessantes, como ciclo menstrual e nível de saturação\nO post 5 motivos para você investir em um smartwatch e melhorar sua saúde apareceu primeiro em Olhar Digital.',
#    'url': 'https://olhardigital.com.br/2023/03/21/dicas-e-tutoriais/5-motivos-para-voce-investir-em-um-smartwatch-e-melhorar-sua-saude/',
#    'urlToImage': 'https://img.olhardigital.com.br/wp-content/uploads/2023/03/simon-daoudi-2wFoa040m8g-unsplash.jpg',
#    'publishedAt': '2023-03-21T11:40:00Z',
#    'content': 'O smartwatch (â\x80\x9crelÃ³gio inteligenteâ\x80\x9d, em traduÃ§Ã£o livre) Ã© um dispositivo moderno que se popularizou entre os apreciadores da tecnologia devido Ã\xa0s funÃ§Ãµes disponÃ\xadveis em seu sistema, Ãºtei… [+3826 chars]'},
#   {'source': {'id': None, 'name': 'Interia.pl'},
#    'author': 'INTERIA.PL',
#    'title': 'Reese Witherspoon wyprodukuje ekranizację hitowej powieści o miłości',
#    'description': 'Należąca do Reese Witherspoon firma produkcyjna Hello Sunshine wyprodukuje dla Apple Studios adaptację powieści "Maybe Next Time" Cesci Major. Będzie to kolejna już książka, którą przeniesie na ekran firma należąca do słynnej aktorki. Wcześniej Hello Sunshine…',
#    'url': 'https://film.interia.pl/wiadomosci/news-reese-witherspoon-wyprodukuje-ekranizacje-hitowej-powiesci-o,nId,6668643',
#    'urlToImage': 'https://i.iplsc.com/-/000GX5JP3N15P3BD-C429-F4.jpg',
#    'publishedAt': '2023-03-21T11:38:59Z',
#    'content': 'Powie "Maybe Next Time" trafia na amerykaskie póki ksigarskie na pocztku marca tego roku i z miejsca staa si hitem. Ksika Major okrelana jest jako najbardziej wzruszajca i chwalca ycie opowie miosna … [+1875 chars]'},
#   {'source': {'id': None, 'name': 'Spidersweb.pl'},
#    'author': 'przemyslaw.pajak@gmail.com (Przemysław Pająk)',
#    'title': 'Chcesz jak najmniej stracić na kupnie smartfona? Kup iPhone’a',
#    'description': '55 proc. – tyle wynosi udział smartfonów klasy premium – tych kosztujących powyżej 600 dol – w ogólnym torcie przychodowym rynku smartfonów. 75 proc. z tego jest udziałem – a jakże – Apple’a.\nNiedawno pisaliśmy o tym, że rynek smartfonów zanotował dotkliwy 12…',
#    'url': 'https://spidersweb.pl/2023/03/smartfony-premium-iphone-wartosc.html',
#    'urlToImage': 'https://ocs-pl.oktawave.com/v1/AUTH_2887234e-384a-4873-8bc5-405211db13a2/spidersweb/2023/03/iphone-14-plus-zolty-kolor-0.jpeg',
#    'publishedAt': '2023-03-21T11:37:18Z',
#    'content': 'Niedawno pisalimy o tym, e rynek smartfonów zanotowa dotkliwy 12 proc. spadek przychodów w zeszym roku, gównie ze wzgldu na niekorzystne warunki makroekonomiczne, tj. kryzys, czy inflacja. Warto jedn… [+330 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Subhrojit Mallick',
#    'title': 'Apple pushed smartphone ASPs to a record $224 in 2022: IDC',
#    'description': 'Apple’s iPhone shipments grew to a record 6.7 million units in 2022 from 4.8 million in 2021, with an average selling price of Rs 80,000, the highest in the industry, as per IDC India. At the same time, Samsung shipped 26.1 million units, but at an ASP of $35…',
#    'url': 'https://economictimes.indiatimes.com/industry/cons-products/electronics/apple-pushed-smartphone-asps-to-a-record-224-in-2022-idc/articleshow/98866330.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-98866283,width-1070,height-580,imgsize-95642,overlay-economictimes/photo.jpg',
#    'publishedAt': '2023-03-21T11:36:45Z',
#    'content': 'Indias smartphone average selling price (ASP) hit a record $224 in 2022, up 18% on year, pushed by sales of higher priced devices from Apple and Samsung and pushed by a roughly 30% increase in dollar… [+3196 chars]'},
#   {'source': {'id': None, 'name': 'Securitylab.ru'},
#    'author': 'Alexander Antipov',
#    'title': 'Австралийский финтех отключился от сети и прекратил обслуживать клиентов из-за кибератаки',
#    'description': 'Утечка данных также затронула корпорацию Apple.',
#    'url': 'https://www.securitylab.ru/news/537077.php',
#    'urlToImage': 'https://www.securitylab.ru/upload/iblock/f19/8g4ze0uggrv65ky1k9it3yca45r1vn96.jpg',
#    'publishedAt': '2023-03-21T11:35:50Z',
#    'content': '14:35 / 21 , 20232023-03-21T14:35:50+03:00 Apple.\r\nLatitude Financial - , , , . , .\r\n" \r\ndata-html="true" data-original-title="Latitude Financial"\r\n&gt;Latitude Financial , Latitude Financial , . Lat… [+167 chars]'},
#   {'source': {'id': None, 'name': '24/7 Wall St.'},
#    'author': 'Paul Ausick',
#    'title': 'Before the Bell: First Republic Recovers a Little; Tech Megacaps Jockey for Position',
#    'description': 'The banking crisis is not over yet, but investors appear to be satisfied for now that the world is not about to end.',
#    'url': 'https://247wallst.com/investing/2023/03/21/before-the-bell-first-republic-recovers-a-little-tech-megacaps-jockey-for-position/',
#    'urlToImage': 'https://247wallst.com/wp-content/uploads/2022/03/imageForEntry16-dJZ.jpg',
#    'publishedAt': '2023-03-21T11:35:48Z',
#    'content': 'Premarket action on Tuesday had the three major U.S. indexes trading higher. The Dow Jones industrials were up 0.82%, the S&amp;P 500 up 0.66% and the Nasdaq 0.33% higher.\r\nAll 11 market sectors clos… [+4989 chars]'},
#   {'source': {'id': 'techradar', 'name': 'TechRadar'},
#    'author': 'axel.metz@futurenet.com (Axel Metz)',
#    'title': 'New iPhone 15 rumor hints at our worst USB-C charging fears',
#    'description': 'You may have to buy a brand-new Apple charger to get the fastest iPhone 15 charging speeds.',
#    'url': 'https://www.techradar.com/news/new-iphone-15-rumor-hints-at-our-worst-usb-c-charging-fears',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/3LNZht9WtLEu7C8MTd72xR-1200-80.jpg',
#    'publishedAt': '2023-03-21T11:34:23Z',
#    'content': 'We’re all but certain that Apple plans to embrace USB-C with its upcoming iPhone 15 line, and new rumors suggest that the company’s proprietary USB-C chargers will offer faster charging speeds than a… [+2466 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'techcrunch.com',
#    'title': 'Consumers are splurging on premium smartphones amid tough economic conditions, report says',
#    'description': 'Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone market’s revenue, according to a report from Counterpoint. The analytics company’s report says that premium d…',
#    'url': 'https://biztoc.com/x/9150cf71ab93e47e',
#    'urlToImage': 'https://c.biztoc.com/p/9150cf71ab93e47e/og.webp',
#    'publishedAt': '2023-03-21T11:34:04Z',
#    'content': 'Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone markets revenue, according to a report from Count… [+309 chars]'},
#   {'source': {'id': None, 'name': 'Daily Mail'},
#    'author': 'Lauren Haughey',
#    'title': "iPhone users complain Apple's autocorrect is 'ruining their lives' in the latest iOS update",
#    'description': "Complaints surrounding Apple's autocorrect function have flooded\xa0Twitter over the past few days with users claiming that it wrongly alters words in typed texts.",
#    'url': 'https://www.dailymail.co.uk/sciencetech/article-11884715/iPhone-users-complain-Apples-autocorrect-ruining-lives-latest-iOS-update.html',
#    'urlToImage': 'https://i.dailymail.co.uk/1s/2023/03/21/09/68932405-0-image-a-2_1679390714995.jpg',
#    'publishedAt': '2023-03-21T11:33:58Z',
#    'content': "iPhone users have slammed Apple's 'atrocious' autocorrect feature amidst allegations that it has gotten 'worse and worse' following the most recent\xa0iOS updates.\r\nComplaints surrounding Apple's autoco… [+4727 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'feedfeeder',
#    'title': "The Morning After: Xbox's mobile game store could arrive next year",
#    'description': 'Microsoft could launch an Xbox store on iOS and Android as early as next year, according to a Financial Times interview with Phil Spencer. Microsoft first revealed it was working on an Xbox store for mobile devices in a document filed with the UK’s Competitio…',
#    'url': 'https://slashdot.org/firehose.pl?op=view&amp;id=170588335',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:33:27Z',
#    'content': 'Microsoft could launch an Xbox store on iOS and Android as early as next year, according to a Financial Times interview with Phil Spencer. Microsoft first revealed it was working on an Xbox store for… [+4564 chars]'},
#   {'source': {'id': 'abc-news', 'name': 'ABC News'},
#    'author': 'ZEN SOO AP Technology Writer',
#    'title': 'Google suspends Chinese shopping app amid security concerns',
#    'description': 'Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources',
#    'url': 'https://abcnews.go.com/Technology/wireStory/google-suspends-chinese-shopping-app-amid-security-concerns-98009062',
#    'urlToImage': 'https://s.abcnews.com/images/US/abc_news_default_2000x2000_update_16x9_992.jpg',
#    'publishedAt': '2023-03-21T11:32:21Z',
#    'content': 'HONG KONG -- Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said in a statement Tuesday that … [+1202 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'feedfeeder',
#    'title': "8BitDo's SNES Controller and More Finally Work on Apple Devices - IGN",
#    'description': "8BitDo's SNES Controller and More Finally Work on Apple DevicesIGN 8BitDo makes the Mac great for retro games—iPhone? Not so muchArs Technica 8BitDo Controllers Now Work With iPhones, iPads, Macs, Apple TVGizmodo 8BitDo controllers now work with Apple devices…",
#    'url': 'https://slashdot.org/firehose.pl?op=view&amp;id=170588327',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:32:06Z',
#    'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'},
#   {'source': {'id': None, 'name': 'Giga'},
#    'author': 'Kaan Gürayer',
#    'title': 'Apple trickst die EU aus: Neuer iPhone-Zwang wird zum Goldesel',
#    'description': 'Hallo, USB-C: Im iPhone 15 soll Apple einen neuen Ladeanschluss verbauen. Freiwillig geschieht das aber nicht, dahinter steckt eine neue EU-Vorgabe. Doch Apple wäre nicht Apple, wenn der US-Konzern nicht noch ein Ass im Ärmel hätte.',
#    'url': 'https://www.giga.de/news/apple-trickst-die-eu-aus-neuer-iphone-zwang-wird-zum-goldesel/',
#    'urlToImage': 'https://crops.giga.de/70/89/38/d8453386eebc88c08a4bd2535f_YyA0NjMyeDI0MjArMTQ4KzQzMAJyZSAxMjAwIDYyNwM3OWQ1OGU4MDQyNQ==.jpg',
#    'publishedAt': '2023-03-21T11:31:59Z',
#    'content': 'Hallo, USB-C: Im iPhone 15 soll Apple einen neuen Ladeanschluss verbauen. Freiwillig geschieht das aber nicht, dahinter steckt eine neue EU-Vorgabe. Doch Apple wäre nicht Apple, wenn der US-Konzern n… [+1718 chars]'},
#   {'source': {'id': None, 'name': 'Frandroid'},
#    'author': 'Théo Sire',
#    'title': 'Apple : pourquoi le retard du HomePod 3 serait une très mauvaise nouvelle pour le monde entier',
#    'description': "Objet de rumeurs depuis bientôt deux ans, le prochain modèle d'enceinte connectée d'Apple, le HomePod 3, pourrait ne pas sortir avant 2024 au minimum, selon le média en ligne Bloomberg. Une mesure d'économie parmi d'autres de la firme de Cupertino pour éviter…",
#    'url': 'https://www.frandroid.com/marques/apple/1640213_apple-pourquoi-le-retard-du-homepod-3-serait-une-tres-mauvaise-nouvelle-pour-le-monde-entier',
#    'urlToImage': 'https://images.frandroid.com/wp-content/uploads/2023/03/homepod-facetime-3d-blue.jpeg',
#    'publishedAt': '2023-03-21T11:31:02Z',
#    'content': "Objet de rumeurs depuis bientôt deux ans, le prochain modèle d'enceinte connectée d'Apple, le HomePod 3, pourrait ne pas sortir avant 2024 au minimum, selon le média en ligne Bloomberg. Une mesure d'… [+3120 chars]"},
#   {'source': {'id': None, 'name': 'Haber7.com'},
#    'author': 'Ekrem Öztürk',
#    'title': 'İddia sosyal medyayı ikiye böldü... İşte iPhone 15 Pro ile gelen yeni tasarım ve özellik',
#    'description': "Apple, yıllardır kullanılan sessize alma ve sesi açma anahtarının tasarımını değiştiriyor. Yeni özelliğin sadece iPhone 15 Pro ve 15 Ultra'ya geleceği söyleniyor.",
#    'url': 'https://www.haber7.com/teknoloji/haber/3311054-iddia-sosyal-medyayi-ikiye-boldu-iste-iphone-15-pro-ile-gelen-yeni-tasarim-ve-ozellik',
#    'urlToImage': 'https://i20.haber7.net/resize/1280x720//haber/haber7/photos/2023/12/apple_herkesin_sevdigi_o_ozelligin_tasarimini_degistiriyor_1679397569_357.jpg',
#    'publishedAt': '2023-03-21T11:31:00Z',
#    'content': "Apple, 2007 ylndan beri iPhone'larda yer verdii sessize alma ve sesi açma butonunu deitirerek yeni bir tasarma gidiyor. iPhone'u sesli ve sessiz moda almak için kullanclar tarafndan pratik bir yöntem… [+893 chars]"},
#   {'source': {'id': None, 'name': 'Haber7.com'},
#    'author': 'Ekrem Öztürk',
#    'title': "Apple, sosyal medyayı ikiye bölen iPhone'lardaki o özelliğin tasarımını değiştiriyor!",
#    'description': "Apple, yıllardır kullanılan sessize alma ve sesi açma anahtarının tasarımını değiştiriyor. Yeni özelliğin sadece iPhone 15 Pro ve 15 Ultra'ya geleceği söyleniyor.",
#    'url': 'https://www.haber7.com/teknoloji/haber/3311054-apple-sosyal-medyayi-ikiye-bolen-iphonelardaki-o-ozelligin-tasarimini-degistiriyor',
#    'urlToImage': 'https://i20.haber7.net/resize/1280x720//haber/haber7/photos/2023/12/apple_herkesin_sevdigi_o_ozelligin_tasarimini_degistiriyor_1679397569_357.jpg',
#    'publishedAt': '2023-03-21T11:31:00Z',
#    'content': "Apple, 2007 ylndan beri iPhone'larda yer verdii sessize alma ve sesi açma butonunu deitirerek yeni bir tasarma gidiyor. iPhone'u sesli ve sessiz moda almak için kullanclar tarafndan pratik bir yöntem… [+893 chars]"},
#   {'source': {'id': None, 'name': 'Iphoneaddict.fr'},
#    'author': 'Frederic L.',
#    'title': 'Luck (Apple TV+): Apple diffuse un court métrage d’animation avec les personnages du film',
#    'description': 'Voilà qui ressemble beaucoup à ce que faisait Pixar à une certaine époque : Apple a diffusé gratuitement sur YouTube un court métrage d’animation avec les personnages du film Luck. Intitulé Bad Luck Spot, ce court d’environ 5 minutes met en scène les petits «…',
#    'url': 'https://iphoneaddict.fr/post/news-359816-luck-apple-tv-apple-diffuse-court-metrage-danimation-personnages-film',
#    'urlToImage': 'https://static.iphoneaddict.fr/wp-content/uploads/2023/03/Luck-Apple-TV.jpg',
#    'publishedAt': '2023-03-21T11:30:57Z',
#    'content': 'Voilà qui ressemble beaucoup à ce que faisait Pixar à une certaine époque : Apple a diffusé gratuitement sur YouTube un court métrage d’animation avec les personnages du film Luck. Intitulé Bad Luck … [+879 chars]'},
#   {'source': {'id': None, 'name': 'Macerkopf.de'},
#    'author': 'Admin',
#    'title': 'iPhone 15: MFi-Anforderungen wird Nachfrage nach USB-C Ladegeräten steigern',
#    'description': 'Seit mehreren Jahren – genau genommen seit dem Jahr 2020 – legt Apple beim Kauf eines neuen iPhone-Modells kein USB-Ladegerät mehr bei. Diese Entscheidung wurden anfänglich von einigen Anwender kritisiert. Diese warfen Apple vor, die Entscheidung nicht aus Um…',
#    'url': 'https://www.macerkopf.de/2023/03/21/iphone15-mfi-anforderungen-nachfrage-usb/',
#    'urlToImage': 'https://www.macerkopf.de/wp-content/uploads/2023/03/anker_523_47w_usb_c_netzteil_nano3.jpg',
#    'publishedAt': '2023-03-21T11:30:53Z',
#    'content': 'Seit mehreren Jahren – genau genommen seit dem Jahr 2020 – legt Apple beim Kauf eines neuen iPhone-Modells kein USB-Ladegerät mehr bei. Diese Entscheidung wurden anfänglich von einigen Anwender kriti… [+1888 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Jason Struss',
#    'title': 'The Mandalorian season 3, episode 4 release date, time, channel, and plot',
#    'description': 'What time does episode 4 of The Mandalorian season 3 stream? Is it about Grogu? Digital Trends has all the information about the hit Disney+ Star Wars show.',
#    'url': 'https://www.digitaltrends.com/movies/the-mandalorian-season-3-episode-4-release-date-time-channel-plot/',
#    'urlToImage': 'https://www.digitaltrends.com/wp-content/uploads/2023/03/mandalorian-season-3-ep-4-2.jpg?resize=1200%2C630&p=1',
#    'publishedAt': '2023-03-21T11:30:34Z',
#    'content': 'Everyone’s favorite baby Yoda has returned! After a two-year hiatus that seemed to last forever, The Mandalorian\xa0has triumphantly returned to the small screen. The groundbreaking show proved the Star… [+3264 chars]'},
#   {'source': {'id': None, 'name': 'Techblog.gr'},
#    'author': 'Σπύρος Τζάνης',
#    'title': 'Οι gamers της Apple μπορούν να χρησιμοποιούν νέα χειριστήρια',
#    'description': 'Οι κάτοχοι συσκευών iOS και οι συνδρομητές του Apple Arcade, μπορούν πλέον να χρησιμοποιούν νέα χειριστήρια καθώς το 8BitDo έχει ενημερώσει τους ελεγκτές τρίτων κατασκευαστών.\nΟι gamers της Apple μπορούν να χρησιμοποιούν νέα χειριστήρια - Techblog',
#    'url': 'https://techblog.gr/mobile/oi-gamers-tis-apple-mporoyn-na-chrisimopoioyn-nea-cheiristiria/',
#    'urlToImage': 'https://techblog.gr/wp-content/uploads/2023/03/apple-gamers.png',
#    'publishedAt': '2023-03-21T11:30:21Z',
#    'content': 'Οι κάτοχοι συσκευών iOS και οι συνδρομητές του Apple Arcade, μπορούν πλέον να χρησιμοποιούν νέα χειριστήρια καθώς το 8BitDo έχει ενημερώσει τους ελεγκτές τρίτων κατασκευαστών. Στόχος είναι να υποστηρ… [+842 chars]'},
#   {'source': {'id': None, 'name': 'Poynter'},
#    'author': 'Tom Jones',
#    'title': 'Meet the (angry) press as the White House press conference flies off the rails',
#    'description': 'One reporter lashed out at press secretary Karine Jean-Pierre. Other journalists scolded him. Jean-Pierre threatened to shut the whole thing down.',
#    'url': 'https://www.poynter.org/newsletters/2023/white-house-press-conference-ted-lasso-karine-jean-pierre/',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:30:17Z',
#    'content': 'Were used to seeing some contention in the White House press conferences. Contentious reporters asking pointed questions. Exasperated press secretaries rolling eyes. Awkward and angry exchanges betwe… [+14815 chars]'},
#   {'source': {'id': None, 'name': 'Caschys Blog'},
#    'author': 'André Westphal',
#    'title': 'Apple iPhone 15: Wechsel zu USB-C zeichnet sich bereits ab',
#    'description': 'Apple soll nach aktuellen Gerüchten für die kommenden iPhone 15 den Lightning-Port zu den Akten legen. Stattdessen werde das Unternehmen auf USB-C umsatteln. Öffentlich wird man aus Imagegründen sicherlich andere Argumente anführen, aber Hintergrund sind natü…',
#    'url': 'https://stadt-bremerhaven.de/apple-iphone-15-wechsel-zu-usb-c-zeichnet-sich-bereits-ab/',
#    'urlToImage': 'https://stadt-bremerhaven.de/wp-content/uploads/2023/03/Kuo-USB-C.jpg',
#    'publishedAt': '2023-03-21T11:30:01Z',
#    'content': 'Apple soll nach aktuellen Gerüchten für die kommenden iPhone 15 den Lightning-Port zu den Akten legen. Stattdessen werde das Unternehmen auf USB-C umsatteln. Öffentlich wird man aus Imagegründen sich… [+1114 chars]'},
#   {'source': {'id': None, 'name': 'Canaltech.com.br'},
#    'author': 'Vinícius Moschen',
#    'title': 'Computador da Apple estimado em quase US$ 2 mil é leiloado por US$ 250',
#    'description': 'Um usuário do Reddit, que se identifica como “Bullet_InUr_Head”, acaba de fazer um grande negócio. Após dar um lance de US$ 250 (cerca de R$ 1.310 em conversão direta) em um leilão nos EUA, ele descobriu que a caixa comprada continha um computador antigo da A…',
#    'url': 'https://canaltech.com.br/desktop/computador-da-apple-estimado-em-quase-us-2-mil-e-leiloado-por-us-250-243772/',
#    'urlToImage': 'https://t.ctcdn.com.br/hpP_6WU913RMYOzyN-ScCLeFOyI=/0x0:799x469/799x449/smart/i710644.png',
#    'publishedAt': '2023-03-21T11:30:00Z',
#    'content': 'Um usuário do Reddit, que se identifica como Bullet_InUr_Head, acaba de fazer um grande negócio. Após dar um lance de US$ 250 (cerca de R$ 1.310 em conversão direta) em um leilão nos EUA, ele descobr… [+1603 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Travis Peters, Forbes Councils Member, \n Travis Peters, Forbes Councils Member\n https://www.forbes.com/sites/forbesagencycouncil/people/travispeters1/',
#    'title': 'Reaching The Unreachable: How Brands Are Connecting To Consumers In A World Of Ad Avoidance',
#    'description': 'As ad-based everything seemingly reaches its plateau, how will brands continue to build awareness and buy back attention from distracted consumers?',
#    'url': 'https://www.forbes.com/sites/forbesagencycouncil/2023/03/21/reaching-the-unreachable-how-brands-are-connecting-to-consumers-in-a-world-of-ad-avoidance/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/63e51472e3d4dd6e58361abd/0x0.jpg?format=jpg&width=1200',
#    'publishedAt': '2023-03-21T11:30:00Z',
#    'content': "CEO &amp; Founder of leading product placement agency EightPM.\r\ngetty\r\nIt's almost impossible to imagine a world without advertising, long before the days of social media, print, radio and television… [+5153 chars]"},
#   {'source': {'id': None, 'name': 'MacGeneration'},
#    'author': 'Nicolas Furno',
#    'title': 'Un bug dans la bêta de Ventura aurait conduit à la perte de toutes les photos iCloud',
#    'description': 'Le patron de Koingo Software, un petit éditeur canadien d’apps pour le Mac qui existe depuis 1995, a subi un énorme bug en testant la dernière bêta de macOS Ventura sur son Mac. L’app Photos a planté et au lancement, les 6\xa0000\xa0images qu’elle contenait avaient…',
#    'url': 'https://www.macg.co/macos/2023/03/un-bug-dans-la-beta-de-ventura-aurait-conduit-la-perte-de-toutes-les-photos-icloud-135565',
#    'urlToImage': 'https://cdn.mgig.fr/2023/03/mga-6eaf2008-w375-w1500-w750_accroche.jpg',
#    'publishedAt': '2023-03-21T11:30:00Z',
#    'content': 'Le patron de Koingo Software, un petit éditeur canadien dapps pour le Mac qui existe depuis 1995, a subi un énorme bug en testant la dernière bêta de macOS Ventura sur son Mac. Lapp Photos a planté e… [+3345 chars]'},
#   {'source': {'id': None, 'name': 'New York Post'},
#    'author': 'Joseph Staszewski',
#    'title': 'Rick Pitino celebrates becoming new St. John’s coach with toast at Manhattan hotel',
#    'description': 'Rick Pitino was the toast of the town on Monday, and he did exactly that after accepting the St. John’s head coaching job.',
#    'url': 'https://nypost.com/2023/03/21/rick-pitino-celebrates-st-johns-coach-job-at-manhattan-hotel/',
#    'urlToImage': 'https://nypost.com/wp-content/uploads/sites/2/2023/03/032023PITINO1WM.jpg?quality=75&strip=all&w=1024',
#    'publishedAt': '2023-03-21T11:30:00Z',
#    'content': 'Rick Pitino was the toast of the town on Monday, and he did exactly that after accepting the St. Johns head coaching job.\r\nThe 70-year-old Pitino joined coaching disciple Stephen Masiello and agent E… [+2511 chars]'},
#   {'source': {'id': None, 'name': 'Macmagazine.com.br'},
#    'author': 'Douglas Nascimento',
#    'title': 'Brasileiro compra iPhone e recebe um… perfume para bebês!',
#    'description': 'E vamos de mais um post da série "comprei um produto da Apple, mas recebi algo um pouquinho mais barato". Dessa vez, o brasileiro Lucas Portela alega ter comprado um iPhone 11 na Amazon e recebido um… perfume para bebês! Tendo usado as redes sociais para denu…',
#    'url': 'https://macmagazine.com.br/post/2023/03/21/brasileiro-compra-iphone-e-recebe-um-perfume-para-bebes/',
#    'urlToImage': 'https://macmagazine.com.br/wp-content/uploads/2023/03/20-produto-recebido.jpg',
#    'publishedAt': '2023-03-21T11:30:00Z',
#    'content': 'E vamos de mais um post da série “comprei um produto da Apple, mas recebi algo um pouquinho mais barato”. Dessa vez, o brasileiro Lucas Portela alega ter comprado um iPhone 11 na Amazon e recebido um… [+1300 chars]'},
#   {'source': {'id': None, 'name': 'Independent.ie'},
#    'author': 'By Zen Soo, Associated Press',
#    'title': 'Google suspends Chinese shopping app Pinduoduo amid malware concerns',
#    'description': 'Google has suspended the Chinese shopping platform Pinduoduo on its app store after malware was discovered in versions of the app from other sources.',
#    'url': 'https://www.independent.ie/world-news/google-suspends-chinese-shopping-app-pinduoduo-amid-malware-concerns-42397117.html',
#    'urlToImage': 'https://www.independent.ie/world-news/9a4eb/42397116.ece/AUTOCROP/w1240h700/ipanews_e5bd2af8-028b-4bdd-b29f-2d0a1a776c33_1',
#    'publishedAt': '2023-03-21T11:28:15Z',
#    'content': 'Google has suspended the Chinese shopping platform Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said it suspended the Pinduoduo app on th… [+993 chars]'},
#   {'source': {'id': None, 'name': 'Elconfidencial.com'},
#    'author': 'Juan Soto Ivars',
#    'title': "Escucha todos los episodios de 'Lo más odiado', el pódcast de Soto Ivars y Alberto Olmos",
#    'description': 'El Confidencial estrena el nuevo pódcast de Alberto Olmos y Juan Soto Ivars. Existe "lo más leído" y "lo más compartido". Ellos harán, un par de veces al mes, "lo más odiado". Puedes escucharlo gratis en Spotify, Ivoox o Apple Podcast',
#    'url': 'https://www.elconfidencial.com/espana/2023-03-21/podcast-lo-mas-odiado-olmo-soto-ivars_3570911/',
#    'urlToImage': 'https://images.ecestaticos.com/H4ev3Yjnt8wHkG3ERSiN0zM8jSo=/0x0:1920x1080/600x315/filters:fill(white):format(jpg):quality(99):watermark(f.elconfidencial.com/file/bae/eea/fde/baeeeafde1b3229287b0c008f7602058.png,0,275,1)/f.elconfidencial.com/original/847/341/988/84734198889e6ec43d2881b87bc76e69.jpg',
#    'publishedAt': '2023-03-21T11:28:00Z',
#    'content': 'Somos Alberto Olmos y Juan Soto Ivars. Columnistas aquí, en El Confidencial. \r\n Veréis. Nos han propuesto hacer un pódcast. O nos obligan a hacer un pódcast. No estamos seguros. Que por qué no hacemo… [+1492 chars]'},
#   {'source': {'id': None, 'name': 'DIE WELT'},
#    'author': 'Stefan Weißenborn',
#    'title': 'SUV-Bike für Pendler – So gut ist der Alleskönner für 4199 Euro wirklich',
#    'description': 'Das E-Antelao vom norddeutschen Hersteller Stevens ist für Pendler gemacht, die auch mal den asphaltierten Radweg verlassen müssen. Im Test geht das Konzept auf, die Vorteile eines Mountainbikes für den Alltag zu nutzen. Und doch gibt es Grenzen.',
#    'url': 'https://www.welt.de/wirtschaft/webwelt/article244338799/E-Bike-Stevens-E-Antelao-im-Test-So-gut-ist-das-SUV-Bike.html',
#    'urlToImage': 'https://img.welt.de/img/bildergalerien/mobile244338779/3711356387-ci16x9-w1200/Ueber-Glattes-und-Grobes-Unterwegs-mit-einem-Alleskoenner-Bike.jpg',
#    'publishedAt': '2023-03-21T11:27:42Z',
#    'content': 'Alleskönner sind keine Spezialisten. Sie beherrschen oft von vielem ein wenig, aber sind in nichts spitzenmäßig gut. Trifft das auch auf die SUV-Bikes zu? Fahrräder der in letzter Zeit stark in Mode … [+5028 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': "Does an Apple phone get outdated in 3 months: CBI on Sisodia 'destroying phones' - The Indian Express",
#    'description': "<ol><li>Does an Apple phone get outdated in 3 months: CBI on Sisodia 'destroying phones'\xa0\xa0The Indian Express\r\n</li><li>'Wife Unwell, Son Abroad', Says Manish Sisodia In Bail Hearing. CBI Opposes\xa0\xa0NDTV\r\n</li><li>Sisodia's Judicial Custody Extended Till April 3…",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiZGh0dHBzOi8vaW5kaWFuZXhwcmVzcy5jb20vYXJ0aWNsZS9jaXRpZXMvZGVsaGkvY2JpLW9uLXNpc29kaWEtZGVzdHJveWluZy1waG9uZXMtZGVsaGktY291cnQtODUxMDYwMi_SAQA?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:27:24Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': 'Does an Apple phone get outdated in 3 months: CBI on Sisodia ‘destroying phones’ - The Indian Express',
#    'description': "<ol><li>Does an Apple phone get outdated in 3 months: CBI on Sisodia ‘destroying phones’\xa0\xa0The Indian Express\r\n</li><li>'Wife Unwell, Son Abroad', Says Manish Sisodia In Bail Hearing. CBI Opposes\xa0\xa0NDTV\r\n</li><li>Sisodia's Judicial Custody Extended Till April 3…",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.com/rss/articles/CBMiZGh0dHBzOi8vaW5kaWFuZXhwcmVzcy5jb20vYXJ0aWNsZS9jaXRpZXMvZGVsaGkvY2JpLW9uLXNpc29kaWEtZGVzdHJveWluZy1waG9uZXMtZGVsaGktY291cnQtODUxMDYwMi_SAWlodHRwczovL2luZGlhbmV4cHJlc3MuY29tL2FydGljbGUvY2l0aWVzL2RlbGhpL2NiaS1vbi1zaXNvZGlhLWRlc3Ryb3lpbmctcGhvbmVzLWRlbGhpLWNvdXJ0LTg1MTA2MDIvbGl0ZS8?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:27:24Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': None, 'name': 'Webnews.it'},
#    'author': 'Massimo Reina',
#    'title': 'Guardate com’è bello il nuovo Google Pixel Watch: corri a prenderlo su Amazon',
#    'description': 'Google Pixel Watch è finalmente disponibile su Amazon con le spedizioni via Prime: ma dovete fare in fretta, pochi pezzi disponibili.',
#    'url': 'https://www.webnews.it/guardate-come-bello-il-nuovo-google-pixel-watch-corri-a-prenderlo-su-amazon/',
#    'urlToImage': 'https://cdn.webnews.it/Dd-Gba8Mf009fbajT2HXHoIDzp4=/160x160/https://www.webnews.it/app/uploads/2023/03/Google-Pixel-Watchv-e1679397605671.jpg',
#    'publishedAt': '2023-03-21T11:27:18Z',
#    'content': 'Google è da sempre al lavoro per ampliare il più possibile il suo portfolio di prodotti, con l’obiettivo di creare un ecosistema di hardware e software che lavorano insieme per anticipare e reagire a… [+1959 chars]'},
#   {'source': {'id': None, 'name': '9to5Toys'},
#    'author': 'Rikka Altland',
#    'title': 'Spring clearance takes up to $699 off cellular 12.9-inch M1 iPad Pros from $1,000',
#    'description': 'If you haven’t been sold on the M2 devices yet and are still looking for a way to bring iPadOS into your workflow, Best Buy is now discounting Apple’s previous-generation 12.9-inch M1 iPad Pro. Putting cellular configurations in the spotlight, pricing now sta…',
#    'url': 'https://9to5toys.com/2023/03/21/m1-12-9-inch-ipad-pro-spring-sale/',
#    'urlToImage': 'https://i0.wp.com/9to5toys.com/wp-content/uploads/sites/5/2021/06/iPad-Pro-2021-Review.jpg?resize=1200%2C628&ssl=1',
#    'publishedAt': '2023-03-21T11:26:58Z',
#    'content': 'If you havent been sold on the M2 devices yet and are still looking for a way to bring iPadOS into your workflow, Best Buy is now discounting Apples previous-generation 12.9-inch M1 iPad Pro. Putting… [+2362 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'washingtonpost.com',
#    'title': 'Google suspends Chinese shopping app amid security concerns',
#    'description': 'HONG KONG — Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources. Google said in a statement Tuesday that it suspended the Pinduoduo app on the Google Play app store ou…',
#    'url': 'https://biztoc.com/x/b143766d613f6b16',
#    'urlToImage': 'https://c.biztoc.com/168/og.png',
#    'publishedAt': '2023-03-21T11:26:25Z',
#    'content': 'HONG KONG Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources. Google said in a statement Tuesday that it s… [+300 chars]'},
#   {'source': {'id': None, 'name': 'MobileSyrup'},
#    'author': 'Ian Hardy',
#    'title': 'Apple AirPods Max, 2nd and 3rd-Gen AirPods are up to 17 percent off today',
#    'description': 'Check out these great deals on Apple wireless headphones and earbuds. You can save on both the AirPods Max and the 2nd and 3rd-generation AirPods which are currently on sale. Apple AirPods Max – Green for $719.98 (save 8%) Apple AirPods (2nd Generation) for $…',
#    'url': 'https://mobilesyrup.com/2023/03/21/apple-airpods-amazon-max-google/',
#    'urlToImage': 'https://cdn.mobilesyrup.com/wp-content/uploads/2020/12/airpods-max-waterfield-case-1-1.jpg',
#    'publishedAt': '2023-03-21T11:26:21Z',
#    'content': 'Check out these great deals on Apple wireless headphones and earbuds. You can save on both the AirPods Max and the 2nd and 3rd-generation AirPods which are currently on sale.\r\nThe AirPods Max are hig… [+1387 chars]'},
#   {'source': {'id': None, 'name': 'Phonandroid'},
#    'author': 'La Redaction',
#    'title': 'Darty casse le prix des iPad avec jusqu’à 100€ de remise immédiate !',
#    'description': "Grâce à des réductions exceptionnelles valables en ce moment sur les iPad chez Darty, vous pouvez profiter d'une tablette d'Apple à partir de 369,99€ ! On vous détaille plusieurs offres dans cet article. Profiter de l'iPad 10,2″ 64Go à prix...",
#    'url': 'https://www.phonandroid.com/darty-casse-le-prix-des-ipad-avec-jusqua-100e-de-remise-immediate.html',
#    'urlToImage': 'https://img.phonandroid.com/2022/11/ipad-air-darty.jpg',
#    'publishedAt': '2023-03-21T11:25:14Z',
#    'content': "Grâce à des réductions exceptionnelles valables en ce moment sur les iPad chez Darty, vous pouvez profiter d'une tablette d'Apple à partir de 369,99 ! On vous détaille plusieurs offres dans cet artic… [+2095 chars]"},
#   {'source': {'id': None, 'name': 'SamMobile'},
#    'author': 'Mihai Matei',
#    'title': 'Mysterious album art issues fixed by new Samsung Music update',
#    'description': 'A new update for Samsung Music is now available. It’s nothing big, but it does fix one visual issue regarding album artwork. Samsung Music version 16.2.30 is now available from the Galaxy Store. The latest update is minor but fixes “an error related to changi…',
#    'url': 'https://www.sammobile.com/news/mysterious-album-art-issues-fixed-by-new-samsung-music-update/',
#    'urlToImage': 'https://www.sammobile.com/wp-content/uploads/2019/11/samsung-music.jpg',
#    'publishedAt': '2023-03-21T11:24:53Z',
#    'content': 'A new update for Samsung Music is now available. It’s nothing big, but it does fix one visual issue regarding album artwork.\r\nSamsung Music version 16.2.30 is now available from the Galaxy Store. The… [+914 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Ivan Mehta',
#    'title': 'Consumers are splurging on premium smartphones amid tough economic conditions, report says',
#    'description': 'Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone market’s revenue, according to a report from Counterpoint. The analytics company’s report says that premium d…',
#    'url': 'https://techcrunch.com/2023/03/21/consumers-are-splurging-on-premium-smartphones-amid-tough-economic-conditions-report-says/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2022/10/CMC_3800.jpg?resize=1200,800',
#    'publishedAt': '2023-03-21T11:24:13Z',
#    'content': 'Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone market’s revenue, according to a report from Coun… [+2877 chars]'},
#   {'source': {'id': None, 'name': 'Healthtoempower.com'},
#    'author': 'Stefani Ruper',
#    'title': '#420: Heavy Metals in Dark Chocolate, Low Appetite, & Magnesium for the Brain',
#    'description': 'Here are the notes for episode #420 of Well-Fed Women. Be sure to check back every Tuesday for a new episode, and head over to\xa0Apple Podcasts\xa0or\xa0Stitcher\xa0to subscribe! In this episode, Noelle and Stef discuss heavy metals in dark chocolate, low appetite, and …',
#    'url': 'https://www.healthtoempower.com/420-heavy-metals-in-dark-chocolate-low-appetite-magnesium-for-the-brain/',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:23:27Z',
#    'content': 'Here are the notes for episode #420 of Well-Fed Women. Be sure to check back every Tuesday for a new episode, and head over to\xa0Apple Podcasts\xa0or\xa0Stitcher\xa0to subscribe!\r\nIn this episode, Noelle and St… [+2162 chars]'},
#   {'source': {'id': None, 'name': 'seattlepi.com'},
#    'author': 'By ZEN SOO, AP Technology Writer',
#    'title': 'Google suspends Chinese shopping app amid security concerns',
# ...
#    'url': 'https://www.gizchina.com/2023/03/21/iphone-dominates-75-of-the-premium-smartphone-market/',
#    'urlToImage': 'https://www.gizchina.com/wp-content/uploads/images/2022/12/iphone-camera.jpg',
#    'publishedAt': '2023-03-21T11:01:42Z',
#    'content': 'In 2022, the global smartphone market faced macroeconomic difficulties that led to a 12% YoY decline in overall sales. However, there was a contrasting growth in the global\xa0premium smartphone market,… [+4016 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Commanders Wire',
#    'title': 'Where do the Commanders rank among potential ‘Hard Knocks’ options?',
#    'description': 'There are four options. Could the Commanders appear on "Hard Knocks" for the first time?',
#    'url': 'https://commanderswire.usatoday.com/2023/03/21/where-do-the-washington-commanders-rank-among-potential-hard-knocks-options-2023-nfl-season/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/.yjALoXElCr6E74Q60JGyQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05MTQ-/https://media.zenfs.com/en/washington_football_wire_usa_today_sports_articles_166/c849272b60428c17f99f5c38a0f13853',
#    'publishedAt': '2023-03-21T11:01:20Z',
#    'content': 'The NFL began the Hard Knocks series all the way back in 2001 with the defending Super Bowl champion Baltimore Ravens. Over the years, 17 different NFL teams have been featured on the series, with th… [+2295 chars]'},
#   {'source': {'id': None, 'name': 'Gartner.com'},
#    'author': 'Hassan Ennaciri',
#    'title': 'You don’t have to be a MAAMA to start adopting Site Reliability Engineering (SRE) Practices.',
#    'description': 'I have taken many inquiries on Site Reliability Engineering (SRE) in the last couple of years.\xa0 I&O leaders are under high pressure to deliver reliable services at an unprecedented pace.\nThey want to consider SRE, but often worry it is an advanced practice th…',
#    'url': 'https://blogs.gartner.com/hassan-ennaciri/you-dont-have-to-be-a-maama-to-start-adopting-site-reliability-engineering-sre-practices/',
#    'urlToImage': 'https://emtemp.gcom.cloud/ngw/globalassets/gartner-tile.jpg',
#    'publishedAt': '2023-03-21T11:01:07Z',
#    'content': 'I have taken many inquiries on Site Reliability Engineering (SRE) in the last couple of years.\xa0 I&amp;O leaders are under high pressure to deliver reliable services at an unprecedented pace.They want… [+1025 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Talon Abernathy',
#    'title': 'No Checking Account? No Problem — Get One Simply at These 4 Banks',
#    'description': 'Maintaining a personal checking account is practically a necessity in this day and age. Unfortunately, many banks make opening new accounts a hassle. Find...',
#    'url': 'https://finance.yahoo.com/news/no-checking-account-no-problem-110103018.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/OIZtHoPUTZyemsFYdZjTfQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/gobankingrates_644/674d21742f9ef11a747f00df8d097d9a',
#    'publishedAt': '2023-03-21T11:01:03Z',
#    'content': 'Blend Images - JGI/Jamie Grill\r\nMaintaining a personal checking account is practically a necessity in this day and age. Unfortunately, many banks make opening new accounts a hassle.\r\nFind Out: Heres … [+4960 chars]'},
#   {'source': {'id': None, 'name': 'Maddyness.com'},
#    'author': 'Valentin Pringuay',
#    'title': '9 ans après sa création, Blue Frogs Robotics s’apprête à lancer la vente grand public de son robot Buddy',
#    'description': "L’article 9 ans après sa création, Blue Frogs Robotics s’apprête à lancer la vente grand public de son robot Buddy\xa0 est apparu en premier sur Maddyness - Le média pour comprendre l'économie de demain.",
#    'url': 'https://www.maddyness.com/2023/03/21/blue-frogs-robotics-buddy/',
#    'urlToImage': 'https://www.maddyness.com/app/uploads/2023/03/BUDDY_RODOLPHE_.png',
#    'publishedAt': '2023-03-21T11:00:59Z',
#    'content': 'Rodolphe Hasselvander a toujours rêvé de créer ses propres robots. Déjà à lâge de 8 ans, il annonçait vouloir devenir archéologue ou ingénieur en robotique : « Javais une maman qui travaillait dans u… [+6078 chars]'},
#   {'source': {'id': None, 'name': 'Tomshw.it'},
#    'author': 'Orazio Guastella',
#    'title': 'iPhone 15 Pro: Apple modificherà queste due componenti per la prima volta in 16 anni',
#    'description': 'Nuove indiscrezioni sui futuri iPhone 15 sbarcano sul web. Scopriamo insieme quali sono le nuove conferme riguardanti la nuova gamma in arrivo a fine anno.',
#    'url': 'https://www.tomshw.it/smartphone/iphone-15-pro-apple-modifichera-queste-due-componenti-per-la-prima-volta-in-16-anni/',
#    'urlToImage': 'https://www.tomshw.it/images/images/2022/09/iphone-14-pro-247309.jpg',
#    'publishedAt': '2023-03-21T11:00:46Z',
#    'content': "Apple iPhone 15 Pro: Apple modificherà queste due componenti per la prima volta in 16 anni\r\nTom's Hardware vive grazie al suo pubblico. Quando compri qualcosa dai nostri link, potremmo guadagnare una… [+3621 chars]"},
#   {'source': {'id': None, 'name': 'Xatakamovil.com'},
#    'author': 'Alejandro Alcolea',
#    'title': 'El iPhone 15 Pro romperá con el único elemento legado del iPhone original: adiós al interruptor de silencio, según filtraciones',
#    'description': 'Hace 16 años, Steve Jobs presentó el móvil más revolucionario de los últimos años, el iPhone. Es un terminal que estaba en pañales, pero que cambió el rumbo de la industria al introducir, de manera definitiva, un ordenador en el bolsillo. Desde su lanzamiento…',
#    'url': 'https://www.xatakamovil.com/nuevo/iphone-15-pro-rompera-unico-elemento-legado-iphone-original-adios-al-interruptor-silencio-filtraciones',
#    'urlToImage': 'https://i.blogs.es/df1590/slider/840_560.jpeg',
#    'publishedAt': '2023-03-21T11:00:35Z',
#    'content': 'Hace 16 años, Steve Jobs presentó el móvil más revolucionario de los últimos años, el iPhone. Es un terminal que estaba en pañales, pero que cambió el rumbo de la industria al introducir, de manera d… [+2378 chars]'},
#   {'source': {'id': None, 'name': 'Onliner.by'},
#    'author': 'Onliner',
#    'title': 'Письмо с редкой подписью Стива Джобса хотят пустить с молотка за $95 тысяч',
#    'description': 'Подписанное Стивом Джобсом благодарственное письмо выставлено на продажу — за него просят $95 тысяч. Этот лот — достаточно редкий. Стив почти никогда не раздавал автографы.Читать далее…',
#    'url': 'https://tech.onliner.by/2023/03/21/pismo-s-redkoj-podpisyu-stiva-dzhobsa-xotyat-pustit-s-molotka-za-95-tysyach',
#    'urlToImage': 'https://content.onliner.by/news/default/434864afbbece7555e244a9e9e210761.jpeg',
#    'publishedAt': '2023-03-21T11:00:33Z',
#    'content': '$95 . . .\r\n Apple . :\xa0« , Apple. Apple , , . , , , ».\r\n $95 ? . , , , , $500 .\r\n \xa0Telegram. !\r\n ? \xa0-.'},
#   {'source': {'id': None, 'name': 'Presse-citron'},
#    'author': 'Romain Vitt',
#    'title': 'Sur un marché en berne, les smartphones premium se portent bien (surtout les iPhone)',
#    'description': 'Le dernier rapport de Counterpoint sur les ventes de smartphones dans le monde montre que les modèles haut de gamme résistent mieux à la crise que les autres segments. Apple en profite largement grâce à son iPhone 14 qui cartonne.',
#    'url': 'https://www.presse-citron.net/sur-un-marche-en-berne-les-smartphones-premium-se-portent-bien-surtout-les-iphone/',
#    'urlToImage': 'https://www.presse-citron.net/app/uploads/2022/09/iphone-14-pro-gamme.jpg',
#    'publishedAt': '2023-03-21T11:00:30Z',
#    'content': '<ul><li>Le marché des smartphones sest écroulé en 2022 selon Counterpoint Research</li><li>Le segment Premium, lui, résiste mieux à la crise</li><li>Apple en sort grand gagnant</li></ul>Le marché mon… [+3349 chars]'},
#   {'source': {'id': None, 'name': 'Iphoneitalia.com'},
#    'author': 'Francesco Siciliani',
#    'title': 'Audible: tutti gli audiolibri su iPhone, iPad, Mac e CarPlay – RECENSIONE',
#    'description': "Audible è la più diffusa applicazione dedicata agli audiolibri, grazie alla quale è possibile acquistare e ascoltare interi libri.\nLink all'articolo originale: Audible: tutti gli audiolibri su iPhone, iPad, Mac e CarPlay – RECENSIONE",
#    'url': 'https://www.iphoneitalia.com/791716/audible-audiolibri-gratis-amazon-recensione',
#    'urlToImage': 'https://static.iphoneitalia.com/wp-content/uploads/2023/01/Audible.jpg',
#    'publishedAt': '2023-03-21T11:00:26Z',
#    'content': 'Amazon mette a disposizione, con Audible, il suo catalogo di audiolibri in una sola applicazione, disponibile su iPhone, iPad, Mac e persino Apple CarPlay. Troviamo contenuti di altissima qualità e, … [+3261 chars]'},
#   {'source': {'id': None, 'name': 'Antyweb.pl'},
#    'author': 'Krzysztof Rojek',
#    'title': 'Zabicie serii iPhone mini było dobrą decyzją. Oto dlaczego',
#    'description': 'Przez ostatnie dwa lata mieliśmy na rynku kilka małych telefonów. Dane pokazują, dlaczego przez kolejne lata ich nie będzie.\n \n The post Zabicie serii iPhone mini było dobrą decyzją. Oto dlaczego appeared first on AntyWeb.',
#    'url': 'https://antyweb.pl/apple-iphone-14-plus-mini-sprzedaz',
#    'urlToImage': 'https://antyweb.pl/img/1250/550/fit/wp-content/uploads/2020/10/13194421/iPhone-12-Mini-1.jpg',
#    'publishedAt': '2023-03-21T11:00:23Z',
#    'content': 'W temacie telefonów w sieci od lat trwa walka pomidzy zwolennikami maych telefonów oraz urzdze z du przektn ekranu.\xa0 Ta pierwsza grupa jest duo goniejsza i w wielu miejscach moecie przeczyta, jak to … [+2194 chars]'},
#   {'source': {'id': None, 'name': 'Ipadizate.com'},
#    'author': 'Sergio J. Ortiz',
#    'title': 'Rusia prohíbe el iPhone a sus usuarios: "que lo tiren a la basura"',
#    'description': 'Después de que el director de WhatsApp atacase a Telegram de espionaje y ante la inminente llegada de las elecciones presidenciales, el Kremlin ha prohibido el uso de iPhone a sus oficiales debido a las preocupaciones existentes en relación a "la vulnerabilid…',
#    'url': 'https://ipadizate.com/iphone/rusia-prohibe-el-iphone-a-sus-usuarios-que-lo-tiren-a-la-basura',
#    'urlToImage': 'https://ipadizate.com/hero/2023/03/putin.1679394002.5699.jpg?width=1200',
#    'publishedAt': '2023-03-21T11:00:20Z',
#    'content': 'El gobierno ruso desea evitar filtraciones relacionadas con las elecciones\r\nDespués de que el director de WhatsApp atacase a Telegram de espionaje y ante la inminente llegada de las elecciones presid… [+2165 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'Celtics Wire',
#    'title': 'Do the fans of the Boston Celtics expect too much from the team?',
#    'description': 'Is winning and momentum more important than playoff readiness and health?',
#    'url': 'https://celticswire.usatoday.com/2023/03/21/nba-boston-celtics-too-much/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/XpRBkQA0V8IKNzcex5LZnA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/celtics_wire_usa_today_sports_articles_699/9e5112a4d48f5541e410a4db4ae880db',
#    'publishedAt': '2023-03-21T11:00:17Z',
#    'content': 'Do the fans of the Boston Celtics expect too much from the team? On one hand, they want the ball club to win every game they can in the 2022-23 regular season. But on the other, they also want the te… [+869 chars]'},
#   {'source': {'id': None, 'name': 'Actualidadiphone.com'},
#    'author': 'Alex Vicente',
#    'title': 'La Xbox App Store podría llegar al iPhone el año que viene',
#    'description': 'Microsoft está preparándose para lanzar la Xbox App Store si la regulación obliga finalmente a Apple a abrir su ecosistema a terceros.',
#    'url': 'https://www.actualidadiphone.com/la-xbox-app-store-podria-llegar-al-iphone-el-ano-que-viene/',
#    'urlToImage': 'https://www.actualidadiphone.com/wp-content/uploads/2021/06/xbox-cloud-gaming.jpg',
#    'publishedAt': '2023-03-21T11:00:15Z',
#    'content': 'Microsoft ya está trabajando duro para prepararse para un mundo en el que Apple se vea obligada a permitir tiendas de aplicaciones de terceros en el iPhone. En una entrevista con el Financial Times, … [+2423 chars]'},
#   {'source': {'id': None, 'name': 'Nextpit.com'},
#    'author': 'Matthias "MaTT" Zellmer',
#    'title': 'Apple iPhone 15 Pro: Take a First Look at the Rumored "Taptic Buttons"',
#    'description': 'It is not a big secret that many leakers assume that the Apple iPhone 15 Pro (Max) will come with new "Taptic Buttons". Here is a first picture.(This is a preview - click here to read the entire entry.)',
#    'url': 'https://www.nextpit.com/apple-iphone-15-pro-new-taptic-buttons',
#    'urlToImage': 'https://fscl01.fonpit.de/userfiles/7687254/image/Apple_iPhone_14_Pro_Max/NextPit_Apple_iPhone_14_Pro_Max_Side.jpg',
#    'publishedAt': '2023-03-21T11:00:01Z',
#    'content': 'This is probably what the "taptic buttons" of the Apple iPhone 15 Pro will look like\r\nIt will be another six months before we get the Apple iPhone 15 series announced by Tim Cook. Nevertheless, tipst… [+1967 chars]'},
#   {'source': {'id': 'google-news', 'name': 'Google News'},
#    'author': None,
#    'title': "'Wife Unwell, Son Abroad', Says Manish Sisodia In Bail Hearing. CBI Opposes - NDTV",
#    'description': "<ol><li>'Wife Unwell, Son Abroad', Says Manish Sisodia In Bail Hearing. CBI Opposes\xa0\xa0NDTV\r\n</li><li>Sisodia's Judicial Custody Extended Till April 3; Bail Hearing Today\xa0\xa0Republic World\r\n</li><li>Rahul Gandhi renews 'democracy under attack' charge; Court exten…",
#    'url': 'https://consent.google.com/ml?continue=https://news.google.?oc%3D5&gl=FR&hl=en-US&cm=2&pc=n&src=1',
#    'urlToImage': None,
#    'publishedAt': '2023-03-21T11:00:01Z',
#    'content': 'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]'},
#   {'source': {'id': None, 'name': 'Nextpit.de'},
#    'author': 'Matthias "MaTT" Zellmer',
#    'title': 'Apple iPhone 15 Pro: So sehen wohl die neuen "Taptic Buttons" aus!',
#    'description': 'Es ist kein großes Geheimnis, dass viele Leaker davon ausgehen, dass das Apple iPhone 15 Pro (Max) mit neuen "Taptic Buttons" kommen. Hier ein erstes Bild.(Dies ist ein Teaser - klick hier, um den kompletten Beitrag zu lesen)',
#    'url': 'https://www.nextpit.de/apple-iphone-15-pro-so-sehen-wohl-die-neuen-taptic-buttons-aus',
#    'urlToImage': 'https://fscl01.fonpit.de/userfiles/7687254/image/Apple_iPhone_14_Pro_Max/NextPit_Apple_iPhone_14_Pro_Max_Side.jpg',
#    'publishedAt': '2023-03-21T11:00:01Z',
#    'content': 'So sehen vermutlich die\xa0"Taptic Buttons" des Apple iPhone 15 Pro (Max) aus\r\nBis wir die Apple-iPhone-15-Serie von Tim Cook präsentiert bekommen, werden noch sechs Monate ins Land gehen. Dennoch sind … [+2190 chars]'},
#   {'source': {'id': None, 'name': 'Tablefortwoblog.com'},
#    'author': 'Julie Chiou',
#    'title': 'Chicken Gyros',
#    'description': 'These Greek-inspired chicken gyros are packed full of marinated chicken breasts inside a warm pita with all the dressings and toppings!',
#    'url': 'https://www.tablefortwoblog.com/chicken-gyros/',
#    'urlToImage': 'https://www.tablefortwoblog.com/wp-content/uploads/2023/03/chicken-gyros-recipe-photo-tablefortwoblog-11-scaled.jpg',
#    'publishedAt': '2023-03-21T11:00:00Z',
#    'content': 'Chicken Gyros feature the most incredible marinated chicken breast meat, fresh veggies, and homemade tzatziki sauce all wrapped up in a pita! These easy to make handheld entrees are Greek in origin a… [+8093 chars]'}]}

# %%
#article_content = response['articles'][0]['content']
#article_content

#all_contents = ''

#for article in response['articles']:
    #content = article['content']
    #all_contents += content

    
articles_content = []
for article in response['articles']:
    content = article['content']
    if content:
        try:
            if langdetect.detect(content) == 'en':
                articles_content.append(content)
        except:
            pass

# %%
articles_content
# Out:
# ['Reply Amazing submit it is stuffed with information and informative content good work stick with it. Are you having points converting the worth of bits into real money, like the US dollar? Then, don’… [+31387 chars]',
#  'WASHINGTON (AP) Fictional soccer coach Ted Lasso used a White House visit Monday to encourage people, even in politically divided Washington, to make it a point to check in often with friends, family… [+3909 chars]',
#  'Microsoft-owned Xbox could be bringing its own app store to your Android and Apple phone according to the company’s gaming chief, Phil Spencer. If it does, we could see some of our favorite apps and … [+3532 chars]',
#  'APPLE PAY: South Koreans can now add their credit or debit card to the Wallet app on their iPhone\r\nApple Pay has launched in South Korea with support for Mastercard, Visa and local debit and credit c… [+1492 chars]',
#  'Indias smartphone average selling price (ASP) hit a record $224 in 2022, up 18% on year, pushed by sales of higher priced devices from Apple and Samsung and pushed by a roughly 30% increase in dollar… [+3196 chars]',
#  'Premarket action on Tuesday had the three major U.S. indexes trading higher. The Dow Jones industrials were up 0.82%, the S&amp;P 500 up 0.66% and the Nasdaq 0.33% higher.\r\nAll 11 market sectors clos… [+4989 chars]',
#  'We’re all but certain that Apple plans to embrace USB-C with its upcoming iPhone 15 line, and new rumors suggest that the company’s proprietary USB-C chargers will offer faster charging speeds than a… [+2466 chars]',
#  'Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone markets revenue, according to a report from Count… [+309 chars]',
#  "iPhone users have slammed Apple's 'atrocious' autocorrect feature amidst allegations that it has gotten 'worse and worse' following the most recent\xa0iOS updates.\r\nComplaints surrounding Apple's autoco… [+4727 chars]",
#  'Microsoft could launch an Xbox store on iOS and Android as early as next year, according to a Financial Times interview with Phil Spencer. Microsoft first revealed it was working on an Xbox store for… [+4564 chars]',
#  'HONG KONG -- Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said in a statement Tuesday that … [+1202 chars]',
#  'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.',
#  'Everyone’s favorite baby Yoda has returned! After a two-year hiatus that seemed to last forever, The Mandalorian\xa0has triumphantly returned to the small screen. The groundbreaking show proved the Star… [+3264 chars]',
#  'Were used to seeing some contention in the White House press conferences. Contentious reporters asking pointed questions. Exasperated press secretaries rolling eyes. Awkward and angry exchanges betwe… [+14815 chars]',
#  "CEO &amp; Founder of leading product placement agency EightPM.\r\ngetty\r\nIt's almost impossible to imagine a world without advertising, long before the days of social media, print, radio and television… [+5153 chars]",
#  'Rick Pitino was the toast of the town on Monday, and he did exactly that after accepting the St. Johns head coaching job.\r\nThe 70-year-old Pitino joined coaching disciple Stephen Masiello and agent E… [+2511 chars]',
#  'Google has suspended the Chinese shopping platform Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said it suspended the Pinduoduo app on th… [+993 chars]',
#  'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]',
#  'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]',
#  'If you havent been sold on the M2 devices yet and are still looking for a way to bring iPadOS into your workflow, Best Buy is now discounting Apples previous-generation 12.9-inch M1 iPad Pro. Putting… [+2362 chars]',
#  'HONG KONG Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources. Google said in a statement Tuesday that it s… [+300 chars]',
#  'Check out these great deals on Apple wireless headphones and earbuds. You can save on both the AirPods Max and the 2nd and 3rd-generation AirPods which are currently on sale.\r\nThe AirPods Max are hig… [+1387 chars]',
#  'A new update for Samsung Music is now available. It’s nothing big, but it does fix one visual issue regarding album artwork.\r\nSamsung Music version 16.2.30 is now available from the Galaxy Store. The… [+914 chars]',
#  'Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone market’s revenue, according to a report from Coun… [+2877 chars]',
#  'Here are the notes for episode #420 of Well-Fed Women. Be sure to check back every Tuesday for a new episode, and head over to\xa0Apple Podcasts\xa0or\xa0Stitcher\xa0to subscribe!\r\nIn this episode, Noelle and St… [+2162 chars]',
#  'HONG KONG (AP) Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said in a statement Tuesday tha… [+1299 chars]',
#  'Good morning!\r\nLeaders dont always have to resort to staffing cuts to shave costs. Just ask Apple.\r\nThe company is one of the very few tech giants to have avoided mass layoffs despite widespread cuts… [+2314 chars]',
#  'Reuters , , , Foxconn, Apple AirPods. 50 000 .\r\nFoxconn . AirPods . Foxconn , , .',
#  'In February, leakers said Apple would limit the benefits of the iPhone 15 USB-C port for MFi products. Now, analyst Ming-Chi Kuo is reiterating these leaks by expecting a significant increase in the … [+2288 chars]',
#  'Oppo Find X6 series launched in China today. The series consists of a base Oppo Find X6 model and an Oppo Find X6 Pro model. The lineup sees a major design overhaul from its predecessors, although th… [+3515 chars]',
#  'Microsoft could launch an Xbox store on iOS and Android as early as next year, according to a Financial Times interview with Phil Spencer. Microsoft first revealed it was working on an Xbox store for… [+4111 chars]',
#  "Skip to contentType your search and hit enter\r\nWhen you purchase through links in our articles, we may earn a small commission. This doesn't affect our editorial independence\r\n.\r\nWe’ve seen multiple … [+5482 chars]",
#  'Opponents argued the bills language is word-for-word in some places like Floridas challenged Stop WOKE Act passed in 2022.\r\nHELENA, Mont. (AP) A Republican lawmaker in Montana wants to prohibit manda… [+4344 chars]',
#  'The Worldcoin orb resembles a bowling ball conceived by Steve Jobs or an oversized Magic 8 ball possessed by HAL 9000. Its glossy exterior envelops the sphere, save for a gaping black circle in the f… [+304 chars]',
#  "KEY POINTS\r\n<ul><li>A post-pandemic surge in demand for business travel led to NYC's ranking</li><li>Switzerland's Geneva and Zurich ranked second and fourth</li><li>Global business travel market is … [+3990 chars]",
#  'Apple stock is breaking out to a new high and is showing strong relative strength. By using a combination of option strategies, we could potentially buy the stock for a significant discount, or achie… [+108 chars]',
#  'Radio shock jock Howard Stern believes former Daily Show host Jon Stewart would win the presidency “in a slam dunk” if he were to run.\xa0\r\nStern, who has floated the idea of running in the past, urged … [+1864 chars]',
#  'The pandemic-led boom that boosted tech companies and their valuations has now turned into a bust in the face of decades-high inflation and rapidly rising interest rates.One of the big news stories i… [+298 chars]',
#  'Apple Inc. is seeking changes in Indias labor laws as part of its effort to expand local production, and regional governments are yielding to its request as they are eager to snatch iPhone assembly f… [+2558 chars]',
#  'Apple Podcasts | Spotify\r\nHosts: Bryce Simon (@MotorCityHoops) and Omari Sankofa II (@omarisankofa)\r\nProducer: Wes Davenport\r\nEditors: Robin Chan\r\nExecutive producers: Anjanette Delgado, Kirkland Cra… [+899 chars]',
#  'Fresh renders for the iPhone 15 Pro have appeared online, revealing the rumoured taptic replacement for the beloved mute switch.\r\nDouyin user chenwen1987 (Douyin being the Chinese version of TikTok) … [+1500 chars]',
#  'Microsoft Activision Blizzard. , Xbox .\r\n Android iOS. Microsoft Xbox .\r\n, Microsoft , . Apple iOS . Android, Google . , Google .\r\n, Microsoft. , Apple Google , Microsoft . , , Androidauthority.',
#  'AUSTIN, TEXAS - MARCH 15: Henk Rogers attends the "Tetris" world premiere at SXSW at The Paramount ... [+] Theatre on March 15, 2023 in Austin, Texas. (Photo by Rick Kern/FilmMagic)\r\nFilmMagic\r\nThe r… [+5621 chars]',
#  'MACRO, the multi-platform media company, founded by Charles D. King, today announced the completion of an over $90 million minority investment led by BlackRock Alternatives, through the BlackRock Imp… [+10054 chars]',
#  'In 2022, the global smartphone market faced macroeconomic difficulties that led to a 12% YoY decline in overall sales. However, there was a contrasting growth in the global\xa0premium smartphone market,… [+4016 chars]',
#  'The NFL began the Hard Knocks series all the way back in 2001 with the defending Super Bowl champion Baltimore Ravens. Over the years, 17 different NFL teams have been featured on the series, with th… [+2295 chars]',
#  'I have taken many inquiries on Site Reliability Engineering (SRE) in the last couple of years.\xa0 I&amp;O leaders are under high pressure to deliver reliable services at an unprecedented pace.They want… [+1025 chars]',
#  'Blend Images - JGI/Jamie Grill\r\nMaintaining a personal checking account is practically a necessity in this day and age. Unfortunately, many banks make opening new accounts a hassle.\r\nFind Out: Heres … [+4960 chars]',
#  '$95 . . .\r\n Apple . :\xa0« , Apple. Apple , , . , , , ».\r\n $95 ? . , , , , $500 .\r\n \xa0Telegram. !\r\n ? \xa0-.',
#  'Do the fans of the Boston Celtics expect too much from the team? On one hand, they want the ball club to win every game they can in the 2022-23 regular season. But on the other, they also want the te… [+869 chars]',
#  'This is probably what the "taptic buttons" of the Apple iPhone 15 Pro will look like\r\nIt will be another six months before we get the Apple iPhone 15 series announced by Tim Cook. Nevertheless, tipst… [+1967 chars]',
#  'We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]',
#  'Chicken Gyros feature the most incredible marinated chicken breast meat, fresh veggies, and homemade tzatziki sauce all wrapped up in a pita! These easy to make handheld entrees are Greek in origin a… [+8093 chars]']

# %%
#this loops through each content key to give each scores

'''
analyzer = SentimentIntensityAnalyzer()
sentiment_scores = []
for content in articles_content:
    score = analyzer.polarity_scores(content)
    sentiment_scores.append(score)
sentiment_scores
'''

# %%
content_string = ''.join(articles_content)
content_string
# Out:
# 'Everyone’s favorite baby Yoda has returned! After a two-year hiatus that seemed to last forever, The Mandalorian\xa0has triumphantly returned to the small screen. The groundbreaking show proved the Star… [+3264 chars]Were used to seeing some contention in the White House press conferences. Contentious reporters asking pointed questions. Exasperated press secretaries rolling eyes. Awkward and angry exchanges betwe… [+14815 chars]CEO &amp; Founder of leading product placement agency EightPM.\r\ngetty\r\nIt\'s almost impossible to imagine a world without advertising, long before the days of social media, print, radio and television… [+5153 chars]Rick Pitino was the toast of the town on Monday, and he did exactly that after accepting the St. Johns head coaching job.\r\nThe 70-year-old Pitino joined coaching disciple Stephen Masiello and agent E… [+2511 chars]Google has suspended the Chinese shopping platform Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said it suspended the Pinduoduo app on th… [+993 chars]We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]We use cookies and data to<ul><li>Deliver and maintain Google services</li><li>Track outages and protect against spam, fraud, and abuse</li><li>Measure audience engagement and site statistics to unde… [+1131 chars]If you havent been sold on the M2 devices yet and are still looking for a way to bring iPadOS into your workflow, Best Buy is now discounting Apples previous-generation 12.9-inch M1 iPad Pro. Putting… [+2362 chars]HONG KONG Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources. Google said in a statement Tuesday that it s… [+300 chars]Check out these great deals on Apple wireless headphones and earbuds. You can save on both the AirPods Max and the 2nd and 3rd-generation AirPods which are currently on sale.\r\nThe AirPods Max are hig… [+1387 chars]A new update for Samsung Music is now available. It’s nothing big, but it does fix one visual issue regarding album artwork.\r\nSamsung Music version 16.2.30 is now available from the Galaxy Store. The… [+914 chars]Amid the declining smartphone market, premium devices are having their moment. These pricy devices made up more than half of the worldwide smartphone market’s revenue, according to a report from Coun… [+2877 chars]Here are the notes for episode #420 of Well-Fed Women. Be sure to check back every Tuesday for a new episode, and head over to\xa0Apple Podcasts\xa0or\xa0Stitcher\xa0to subscribe!\r\nIn this episode, Noelle and St… [+2162 chars]HONG KONG (AP) Google has suspended the Chinese shopping app Pinduoduo on its app store after malware was discovered in versions of the app from other sources.\r\nGoogle said in a statement Tuesday tha… [+1299 chars]Good morning!\r\nLeaders dont always have to resort to staffing cuts to shave costs. Just ask Apple.\r\nThe company is one of the very few tech giants to have avoided mass layoffs despite widespread cuts… [+2314 chars]Reuters , , , Foxconn, Apple AirPods. 50 000 .\r\nFoxconn . AirPods . Foxconn , , .In February, leakers said Apple would limit the benefits of the iPhone 15 USB-C port for MFi products. Now, analyst Ming-Chi Kuo is reiterating these leaks by expecting a significant increase in the … [+2288 chars]Oppo Find X6 series launched in China today. The series consists of a base Oppo Find X6 model and an Oppo Find X6 Pro model. The lineup sees a major design overhaul from its predecessors, although th… [+3515 chars]Microsoft could launch an Xbox store on iOS and Android as early as next year, according to a Financial Times interview with Phil Spencer. Microsoft first revealed it was working on an Xbox store for… [+4111 chars]Skip to contentType your searc ...

# %%
analyzer = SentimentIntensityAnalyzer()
score = analyzer.polarity_scores(content_string)
percentage_score = score['compound']*100
percentage_score = f'{percentage_score} %'
percentage_score = {'percentage_score':percentage_score}
percentage_score
# Out:
# {'percentage_score': '99.88 %'}

# %%
today = date.today()
today
# Out:
# datetime.date(2023, 3, 22)
